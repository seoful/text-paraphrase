# %% [markdown]
# ## Data preparation

# %% [markdown]
# ### Download data

# %%
import requests
from urllib.parse import urlencode
import os

base_url = 'https://cloud-api.yandex.net/v1/disk/public/resources/download?'
public_key = 'https://disk.yandex.ru/d/OdH_N65L66Mj7g'

final_url = base_url + urlencode(dict(public_key=public_key))
response = requests.get(final_url)
download_url = response.json()['href']

download_response = requests.get(download_url)

abs_lib = os.path.abspath('../')
path = abs_lib + '/data/raw'
try:  
    os.mkdir(path)  
except OSError as error:  
    pass

with open('../data/raw/filtered.tsv', 'wb') as f:  
    f.write(download_response.content)

# %%
import numpy as np
import pandas as pd

df = pd.read_csv('../data/raw/dataset.csv',index_col=0)

for i, row in df.iterrows():
    if row['trn_tox'] > row['ref_tox']:
        df.at[i, 'trn_tox'] = row['ref_tox']
        df.at[i, 'ref_tox'] = row['trn_tox']
        df.at[i, 'reference'] = row['translation']
        df.at[i, 'translation'] = row['reference']

df['diff_tox'] = df['ref_tox'] - df['trn_tox']
df['ref_words']= df['reference'].str.split().apply(len)
df['trn_words']= df['translation'].str.split().apply(len)

df.drop(df[((df['ref_words'] > 127) | (df['trn_words'] > 127))].index,inplace=True)
df.to_csv('../data/interim/data.csv')

# %% [markdown]
# ### Manual seed

# %%
import torch
import numpy as np
import pandas as pd
torch.manual_seed(0)
np.random.seed(0)

# %% [markdown]
# ### Read data

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

df = pd.read_csv('../data/interim/data.csv',index_col=0)
df_subset, _ = train_test_split(df,train_size=0.15,shuffle=True)
train, test = train_test_split(df_subset, test_size=0.1,shuffle=True)

# %% [markdown]
# # Models name initialization

# %%
import torch
import evaluate
from transformers import pipeline, RobertaTokenizer, RobertaForSequenceClassification
from sentence_transformers import SentenceTransformer


torch_device = 'cuda' if torch.cuda.is_available() else 'cpu'

paraphrase_model_name = 'humarin/chatgpt_paraphraser_on_T5_base'
toxicity_classifier_name = 'SkolkovoInstitute/roberta_toxicity_classifier'
similarity_embedder_name = 'sentence-transformers/all-MiniLM-L6-v2'
sacrebleu_name = 'sacrebleu'

# %% [markdown]
# ## Train paraphraser

# %%
import datasets

dataset_train = datasets.Dataset.from_pandas(train)
dataset_test = datasets.Dataset.from_pandas(test)

dataset = dataset_train.train_test_split(test_size=0.1)

dataset = datasets.DatasetDict({'train': dataset['train'], "test": dataset_test, "val": dataset['test']})
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['reference', 'translation', 'similarity', 'lenght_diff', 'ref_tox', 'trn_tox', 'diff_tox', 'ref_words', 'trn_words', '__index_level_0__'],
#         num_rows: 70132
#     })
#     test: Dataset({
#         features: ['reference', 'translation', 'similarity', 'lenght_diff', 'ref_tox', 'trn_tox', 'diff_tox', 'ref_words', 'trn_words', '__index_level_0__'],
#         num_rows: 8659
#     })
#     val: Dataset({
#         features: ['reference', 'translation', 'similarity', 'lenght_diff', 'ref_tox', 'trn_tox', 'diff_tox', 'ref_words', 'trn_words', '__index_level_0__'],
#         num_rows: 7793
#     })
# })

# %%
from transformers import AutoModelForSeq2SeqLM,AutoTokenizer

para_tokenizer = AutoTokenizer.from_pretrained(paraphrase_model_name)
para_model = AutoModelForSeq2SeqLM.from_pretrained(paraphrase_model_name).to(torch_device)

# %%
from transformers import DataCollatorForSeq2Seq,Seq2SeqTrainingArguments, Seq2SeqTrainer

data_collator_para = DataCollatorForSeq2Seq(tokenizer=para_tokenizer, model=para_model)

# %%
from peft import LoraModel,LoraConfig,TaskType,get_peft_model

peft_config = LoraConfig(
        r=16, 
        lora_alpha=32,
        target_modules=["q", "v"],
        lora_dropout=0.05,
        bias="none",
        task_type=TaskType.SEQ_2_SEQ_LM
    )
peft_para_model = get_peft_model(para_model,peft_config).to(torch_device)

# %%
def preprocess_para(examples):
    prefix = 'Paraphrase: '
    model_inputs = para_tokenizer([prefix + example for example in examples['reference']], text_target=examples['translation'], truncation=True,padding='longest', return_tensors="pt")
    return model_inputs

para_preprocessed = dataset.map(preprocess_para, batched=True)
# Out:
# Map:   0%|          | 0/70132 [00:00<?, ? examples/s]
# Map:   0%|          | 0/8659 [00:00<?, ? examples/s]
# Map:   0%|          | 0/7793 [00:00<?, ? examples/s]

# %%
training_args = Seq2SeqTrainingArguments(
    output_dir="tensorboard/paraphrase_finetuned",
    evaluation_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    weight_decay=0.01,
    save_total_limit=3,
    num_train_epochs=3,
    logging_steps=10,
    # predict_with_generate=True,
    fp16=True,
)

trainer = Seq2SeqTrainer(
    model=peft_para_model,
    args=training_args,
    train_dataset=para_preprocessed["train"],
    eval_dataset=para_preprocessed["val"],
    tokenizer=para_tokenizer,
    data_collator=data_collator_para,
    # compute_metrics=compute_metrics,
)

trainer.train()
# Out:
#   0%|          | 0/13152 [00:00<?, ?it/s]
# {'loss': 16.2012, 'learning_rate': 1.9984793187347933e-05, 'epoch': 0.0}
# {'loss': 16.5727, 'learning_rate': 1.9969586374695867e-05, 'epoch': 0.0}
# {'loss': 16.0383, 'learning_rate': 1.99543795620438e-05, 'epoch': 0.01}
# {'loss': 15.5488, 'learning_rate': 1.993917274939173e-05, 'epoch': 0.01}
# {'loss': 15.6395, 'learning_rate': 1.992396593673966e-05, 'epoch': 0.01}
# {'loss': 15.5681, 'learning_rate': 1.9908759124087592e-05, 'epoch': 0.01}
# {'loss': 15.0755, 'learning_rate': 1.9893552311435523e-05, 'epoch': 0.02}
# {'loss': 14.2868, 'learning_rate': 1.9878345498783454e-05, 'epoch': 0.02}
# {'loss': 13.9076, 'learning_rate': 1.9864659367396595e-05, 'epoch': 0.02}
# {'loss': 13.4564, 'learning_rate': 1.984945255474453e-05, 'epoch': 0.02}
# {'loss': 13.2906, 'learning_rate': 1.983424574209246e-05, 'epoch': 0.03}
# {'loss': 12.6786, 'learning_rate': 1.981903892944039e-05, 'epoch': 0.03}
# {'loss': 12.5238, 'learning_rate': 1.9803832116788323e-05, 'epoch': 0.03}
# {'loss': 11.9065, 'learning_rate': 1.9788625304136254e-05, 'epoch': 0.03}
# {'loss': 11.3708, 'learning_rate': 1.9773418491484185e-05, 'epoch': 0.03}
# {'loss': 10.5583, 'learning_rate': 1.9758211678832116e-05, 'epoch': 0.04}
# {'loss': 9.6538, 'learning_rate': 1.974300486618005e-05, 'epoch': 0.04}
# {'loss': 9.4114, 'learning_rate': 1.9727798053527982e-05, 'epoch': 0.04}
# {'loss': 8.6678, 'learning_rate': 1.9712591240875913e-05, 'epoch': 0.04}
# {'loss': 8.2614, 'learning_rate': 1.9698905109489053e-05, 'epoch': 0.05}
# {'loss': 7.4195, 'learning_rate': 1.9683698296836984e-05, 'epoch': 0.05}
# {'loss': 6.6793, 'learning_rate': 1.9668491484184916e-05, 'epoch': 0.05}
# {'loss': 6.3359, 'learning_rate': 1.965328467153285e-05, 'epoch': 0.05}
# {'loss': 5.5022, 'learning_rate': 1.963807785888078e-05, 'epoch': 0.05}
# {'loss': 5.0019, 'learning_rate': 1.9622871046228712e-05, 'epoch': 0.06}
# {'loss': 4.2276, 'learning_rate': 1.9607664233576644e-05, 'epoch': 0.06}
# {'loss': 3.9825, 'learning_rate': 1.9592457420924575e-05, 'epoch': 0.06}
# {'loss': 3.6282, 'learning_rate': 1.9577250608272506e-05, 'epoch': 0.06}
# {'loss': 2.8028, 'learning_rate': 1.956204379562044e-05, 'epoch': 0.07}
# {'loss': 2.7547, 'learning_rate': 1.954683698296837e-05, 'epoch': 0.07}
# {'loss': 2.3679, 'learning_rate': 1.9531630170316303e-05, 'epoch': 0.07}
# {'loss': 2.1271, 'learning_rate': 1.9516423357664237e-05, 'epoch': 0.07}
# {'loss': 1.8851, 'learning_rate': 1.950121654501217e-05, 'epoch': 0.08}
# {'loss': 1.6155, 'learning_rate': 1.94860097323601e-05, 'epoch': 0.08}
# {'loss': 1.6279, 'learning_rate': 1.947080291970803e-05, 'epoch': 0.08}
# {'loss': 1.5196, 'learning_rate': 1.9455596107055962e-05, 'epoch': 0.08}
# {'loss': 1.3721, 'learning_rate': 1.9440389294403893e-05, 'epoch': 0.08}
# {'loss': 1.3179, 'learning_rate': 1.9425182481751824e-05, 'epoch': 0.09}
# {'loss': 1.3332, 'learning_rate': 1.940997566909976e-05, 'epoch': 0.09}
# {'loss': 1.1616, 'learning_rate': 1.939476885644769e-05, 'epoch': 0.09}
# {'loss': 1.1225, 'learning_rate': 1.937956204379562e-05, 'epoch': 0.09}
# {'loss': 1.0971, 'learning_rate': 1.9364355231143556e-05, 'epoch': 0.1}
# {'loss': 1.0405, 'learning_rate': 1.9349148418491487e-05, 'epoch': 0.1}
# {'loss': 1.0669, 'learning_rate': 1.9333941605839418e-05, 'epoch': 0.1}
# {'loss': 1.0645, 'learning_rate': 1.931873479318735e-05, 'epoch': 0.1}
# {'loss': 0.9522, 'learning_rate': 1.930352798053528e-05, 'epoch': 0.1}
# {'loss': 0.96, 'learning_rate': 1.928832116788321e-05, 'epoch': 0.11}
# {'loss': 0.8907, 'learning_rate': 1.9273114355231146e-05, 'epoch': 0.11}
# {'loss': 0.9417, 'learning_rate': 1.9257907542579077e-05, 'epoch': 0.11}
# {'loss': 0.9988, 'learning_rate': 1.9242700729927008e-05, 'epoch': 0.11}
# {'loss': 0.9097, 'learning_rate': 1.922749391727494e-05, 'epoch': 0.12}
# {'loss': 0.9134, 'learning_rate': 1.9212287104622874e-05, 'epoch': 0.12}
# {'loss': 0.9244, 'learning_rate': 1.9197080291970805e-05, 'epoch': 0.12}
# {'loss': 0.9135, 'learning_rate': 1.9181873479318736e-05, 'epoch': 0.12}
# {'loss': 0.8606, 'learning_rate': 1.916666666666667e-05, 'epoch': 0.13}
# {'loss': 0.886, 'learning_rate': 1.9151459854014602e-05, 'epoch': 0.13}
# {'loss': 0.7796, 'learning_rate': 1.9136253041362533e-05, 'epoch': 0.13}
# {'loss': 0.9358, 'learning_rate': 1.9121046228710464e-05, 'epoch': 0.13}
# {'loss': 0.8245, 'learning_rate': 1.9105839416058395e-05, 'epoch': 0.13}
# {'loss': 0.7477, 'learning_rate': 1.9090632603406326e-05, 'epoch': 0.14}
# {'loss': 0.8407, 'learning_rate': 1.9075425790754258e-05, 'epoch': 0.14}
# {'loss': 0.8491, 'learning_rate': 1.9060218978102192e-05, 'epoch': 0.14}
# {'loss': 0.7799, 'learning_rate': 1.9045012165450123e-05, 'epoch': 0.14}
# {'loss': 0.843, 'learning_rate': 1.9029805352798054e-05, 'epoch': 0.15}
# {'loss': 0.8543, 'learning_rate': 1.901459854014599e-05, 'epoch': 0.15}
# {'loss': 0.7438, 'learning_rate': 1.899939172749392e-05, 'epoch': 0.15}
# {'loss': 0.7741, 'learning_rate': 1.898418491484185e-05, 'epoch': 0.15}
# {'loss': 0.8739, 'learning_rate': 1.8968978102189782e-05, 'epoch': 0.16}
# {'loss': 0.7473, 'learning_rate': 1.8953771289537714e-05, 'epoch': 0.16}
# {'loss': 0.69, 'learning_rate': 1.8938564476885645e-05, 'epoch': 0.16}
# {'loss': 0.7137, 'learning_rate': 1.892335766423358e-05, 'epoch': 0.16}
# {'loss': 0.7123, 'learning_rate': 1.890815085158151e-05, 'epoch': 0.16}
# {'loss': 0.7604, 'learning_rate': 1.889294403892944e-05, 'epoch': 0.17}
# {'loss': 0.6854, 'learning_rate': 1.8877737226277373e-05, 'epoch': 0.17}
# {'loss': 0.7351, 'learning_rate': 1.8862530413625307e-05, 'epoch': 0.17}
# {'loss': 0.774, 'learning_rate': 1.884732360097324e-05, 'epoch': 0.17}
# {'loss': 0.7973, 'learning_rate': 1.883211678832117e-05, 'epoch': 0.18}
# {'loss': 0.7652, 'learning_rate': 1.88169099756691e-05, 'epoch': 0.18}
# {'loss': 0.7494, 'learning_rate': 1.8801703163017032e-05, 'epoch': 0.18}
# {'loss': 0.703, 'learning_rate': 1.8786496350364963e-05, 'epoch': 0.18}
# {'loss': 0.6669, 'learning_rate': 1.8771289537712897e-05, 'epoch': 0.18}
# {'loss': 0.7088, 'learning_rate': 1.875608272506083e-05, 'epoch': 0.19}
# {'loss': 0.6102, 'learning_rate': 1.874087591240876e-05, 'epoch': 0.19}
# {'loss': 0.6678, 'learning_rate': 1.872566909975669e-05, 'epoch': 0.19}
# {'loss': 0.6693, 'learning_rate': 1.8710462287104625e-05, 'epoch': 0.19}
# {'loss': 0.7071, 'learning_rate': 1.8695255474452557e-05, 'epoch': 0.2}
# {'loss': 0.6503, 'learning_rate': 1.8680048661800488e-05, 'epoch': 0.2}
# {'loss': 0.6687, 'learning_rate': 1.8664841849148422e-05, 'epoch': 0.2}
# {'loss': 0.6848, 'learning_rate': 1.8649635036496353e-05, 'epoch': 0.2}
# {'loss': 0.6978, 'learning_rate': 1.8634428223844285e-05, 'epoch': 0.21}
# {'loss': 0.639, 'learning_rate': 1.8619221411192216e-05, 'epoch': 0.21}
# {'loss': 0.6662, 'learning_rate': 1.8604014598540147e-05, 'epoch': 0.21}
# {'loss': 0.6905, 'learning_rate': 1.8588807785888078e-05, 'epoch': 0.21}
# {'loss': 0.5799, 'learning_rate': 1.8573600973236013e-05, 'epoch': 0.21}
# {'loss': 0.6675, 'learning_rate': 1.8558394160583944e-05, 'epoch': 0.22}
# {'loss': 0.5908, 'learning_rate': 1.8543187347931875e-05, 'epoch': 0.22}
# {'loss': 0.6618, 'learning_rate': 1.8527980535279806e-05, 'epoch': 0.22}
# {'loss': 0.6348, 'learning_rate': 1.851277372262774e-05, 'epoch': 0.22}
# {'loss': 0.632, 'learning_rate': 1.8497566909975672e-05, 'epoch': 0.23}
# {'loss': 0.6166, 'learning_rate': 1.8482360097323603e-05, 'epoch': 0.23}
# {'loss': 0.6592, 'learning_rate': 1.8467153284671534e-05, 'epoch': 0.23}
# {'loss': 0.6881, 'learning_rate': 1.8451946472019465e-05, 'epoch': 0.23}
# {'loss': 0.5727, 'learning_rate': 1.8436739659367396e-05, 'epoch': 0.23}
# {'loss': 0.6231, 'learning_rate': 1.842153284671533e-05, 'epoch': 0.24}
# {'loss': 0.6718, 'learning_rate': 1.8406326034063262e-05, 'epoch': 0.24}
# {'loss': 0.6699, 'learning_rate': 1.8391119221411193e-05, 'epoch': 0.24}
# {'loss': 0.638, 'learning_rate': 1.8375912408759124e-05, 'epoch': 0.24}
# {'loss': 0.6343, 'learning_rate': 1.836070559610706e-05, 'epoch': 0.25}
# {'loss': 0.6226, 'learning_rate': 1.834549878345499e-05, 'epoch': 0.25}
# {'loss': 0.5992, 'learning_rate': 1.833029197080292e-05, 'epoch': 0.25}
# {'loss': 0.6123, 'learning_rate': 1.8315085158150852e-05, 'epoch': 0.25}
# {'loss': 0.5987, 'learning_rate': 1.8299878345498783e-05, 'epoch': 0.26}
# {'loss': 0.6773, 'learning_rate': 1.8284671532846715e-05, 'epoch': 0.26}
# {'loss': 0.6573, 'learning_rate': 1.826946472019465e-05, 'epoch': 0.26}
# {'loss': 0.6698, 'learning_rate': 1.825425790754258e-05, 'epoch': 0.26}
# {'loss': 0.5741, 'learning_rate': 1.823905109489051e-05, 'epoch': 0.26}
# {'loss': 0.6062, 'learning_rate': 1.8223844282238446e-05, 'epoch': 0.27}
# {'loss': 0.6344, 'learning_rate': 1.8208637469586377e-05, 'epoch': 0.27}
# {'loss': 0.5634, 'learning_rate': 1.8193430656934308e-05, 'epoch': 0.27}
# {'loss': 0.5602, 'learning_rate': 1.817822384428224e-05, 'epoch': 0.27}
# {'loss': 0.5406, 'learning_rate': 1.8163017031630174e-05, 'epoch': 0.28}
# {'loss': 0.6396, 'learning_rate': 1.8147810218978105e-05, 'epoch': 0.28}
# {'loss': 0.6443, 'learning_rate': 1.8132603406326036e-05, 'epoch': 0.28}
# {'loss': 0.5616, 'learning_rate': 1.8117396593673967e-05, 'epoch': 0.28}
# {'loss': 0.559, 'learning_rate': 1.81021897810219e-05, 'epoch': 0.29}
# {'loss': 0.5525, 'learning_rate': 1.808698296836983e-05, 'epoch': 0.29}
# {'loss': 0.5165, 'learning_rate': 1.8071776155717764e-05, 'epoch': 0.29}
# {'loss': 0.58, 'learning_rate': 1.8056569343065695e-05, 'epoch': 0.29}
# {'loss': 0.606, 'learning_rate': 1.8041362530413627e-05, 'epoch': 0.29}
# {'loss': 0.5695, 'learning_rate': 1.8026155717761558e-05, 'epoch': 0.3}
# {'loss': 0.5584, 'learning_rate': 1.8010948905109492e-05, 'epoch': 0.3}
# {'loss': 0.5682, 'learning_rate': 1.7995742092457423e-05, 'epoch': 0.3}
# {'loss': 0.5975, 'learning_rate': 1.7980535279805354e-05, 'epoch': 0.3}
# {'loss': 0.5749, 'learning_rate': 1.7965328467153286e-05, 'epoch': 0.31}
# {'loss': 0.5984, 'learning_rate': 1.7950121654501217e-05, 'epoch': 0.31}
# {'loss': 0.5247, 'learning_rate': 1.7934914841849148e-05, 'epoch': 0.31}
# {'loss': 0.5663, 'learning_rate': 1.7919708029197082e-05, 'epoch': 0.31}
# {'loss': 0.5651, 'learning_rate': 1.7904501216545014e-05, 'epoch': 0.31}
# {'loss': 0.5168, 'learning_rate': 1.7889294403892945e-05, 'epoch': 0.32}
# {'loss': 0.4844, 'learning_rate': 1.787408759124088e-05, 'epoch': 0.32}
# {'loss': 0.5688, 'learning_rate': 1.785888077858881e-05, 'epoch': 0.32}
# {'loss': 0.5191, 'learning_rate': 1.784367396593674e-05, 'epoch': 0.32}
# {'loss': 0.4913, 'learning_rate': 1.7828467153284673e-05, 'epoch': 0.33}
# {'loss': 0.5326, 'learning_rate': 1.7813260340632604e-05, 'epoch': 0.33}
# {'loss': 0.5881, 'learning_rate': 1.7798053527980535e-05, 'epoch': 0.33}
# {'loss': 0.559, 'learning_rate': 1.7782846715328466e-05, 'epoch': 0.33}
# {'loss': 0.5324, 'learning_rate': 1.77676399026764e-05, 'epoch': 0.34}
# {'loss': 0.5663, 'learning_rate': 1.7752433090024332e-05, 'epoch': 0.34}
# {'loss': 0.5681, 'learning_rate': 1.7737226277372263e-05, 'epoch': 0.34}
# {'loss': 0.6036, 'learning_rate': 1.7722019464720198e-05, 'epoch': 0.34}
# {'loss': 0.5191, 'learning_rate': 1.770681265206813e-05, 'epoch': 0.34}
# {'loss': 0.5602, 'learning_rate': 1.769160583941606e-05, 'epoch': 0.35}
# {'loss': 0.5753, 'learning_rate': 1.767639902676399e-05, 'epoch': 0.35}
# {'loss': 0.5312, 'learning_rate': 1.7661192214111926e-05, 'epoch': 0.35}
# {'loss': 0.4961, 'learning_rate': 1.7645985401459857e-05, 'epoch': 0.35}
# {'loss': 0.5243, 'learning_rate': 1.7630778588807788e-05, 'epoch': 0.36}
# {'loss': 0.5298, 'learning_rate': 1.761557177615572e-05, 'epoch': 0.36}
# {'loss': 0.5313, 'learning_rate': 1.760036496350365e-05, 'epoch': 0.36}
# {'loss': 0.5599, 'learning_rate': 1.758515815085158e-05, 'epoch': 0.36}
# {'loss': 0.5099, 'learning_rate': 1.7569951338199516e-05, 'epoch': 0.36}
# {'loss': 0.5709, 'learning_rate': 1.7554744525547447e-05, 'epoch': 0.37}
# {'loss': 0.5473, 'learning_rate': 1.7539537712895378e-05, 'epoch': 0.37}
# {'loss': 0.4754, 'learning_rate': 1.7524330900243313e-05, 'epoch': 0.37}
# {'loss': 0.5424, 'learning_rate': 1.7509124087591244e-05, 'epoch': 0.37}
# {'loss': 0.6234, 'learning_rate': 1.7493917274939175e-05, 'epoch': 0.38}
# {'loss': 0.4948, 'learning_rate': 1.7478710462287106e-05, 'epoch': 0.38}
# {'loss': 0.5642, 'learning_rate': 1.7463503649635037e-05, 'epoch': 0.38}
# {'loss': 0.4958, 'learning_rate': 1.744829683698297e-05, 'epoch': 0.38}
# {'loss': 0.4729, 'learning_rate': 1.74330900243309e-05, 'epoch': 0.39}
# {'loss': 0.5226, 'learning_rate': 1.7417883211678834e-05, 'epoch': 0.39}
# {'loss': 0.541, 'learning_rate': 1.7402676399026765e-05, 'epoch': 0.39}
# {'loss': 0.5073, 'learning_rate': 1.7387469586374696e-05, 'epoch': 0.39}
# {'loss': 0.5833, 'learning_rate': 1.737226277372263e-05, 'epoch': 0.39}
# {'loss': 0.5345, 'learning_rate': 1.7357055961070562e-05, 'epoch': 0.4}
# {'loss': 0.5158, 'learning_rate': 1.7341849148418493e-05, 'epoch': 0.4}
# {'loss': 0.5019, 'learning_rate': 1.7326642335766424e-05, 'epoch': 0.4}
# {'loss': 0.5316, 'learning_rate': 1.7311435523114356e-05, 'epoch': 0.4}
# {'loss': 0.5614, 'learning_rate': 1.7296228710462287e-05, 'epoch': 0.41}
# {'loss': 0.4925, 'learning_rate': 1.7281021897810218e-05, 'epoch': 0.41}
# {'loss': 0.545, 'learning_rate': 1.7265815085158152e-05, 'epoch': 0.41}
# {'loss': 0.5348, 'learning_rate': 1.7250608272506084e-05, 'epoch': 0.41}
# {'loss': 0.5553, 'learning_rate': 1.7235401459854015e-05, 'epoch': 0.42}
# {'loss': 0.5926, 'learning_rate': 1.722019464720195e-05, 'epoch': 0.42}
# {'loss': 0.4743, 'learning_rate': 1.720498783454988e-05, 'epoch': 0.42}
# {'loss': 0.5615, 'learning_rate': 1.718978102189781e-05, 'epoch': 0.42}
# {'loss': 0.5028, 'learning_rate': 1.7174574209245746e-05, 'epoch': 0.42}
# {'loss': 0.5594, 'learning_rate': 1.7159367396593677e-05, 'epoch': 0.43}
# {'loss': 0.4589, 'learning_rate': 1.714416058394161e-05, 'epoch': 0.43}
# {'loss': 0.5266, 'learning_rate': 1.712895377128954e-05, 'epoch': 0.43}
# {'loss': 0.5239, 'learning_rate': 1.711374695863747e-05, 'epoch': 0.43}
# {'loss': 0.4733, 'learning_rate': 1.7098540145985402e-05, 'epoch': 0.44}
# {'loss': 0.5203, 'learning_rate': 1.7083333333333333e-05, 'epoch': 0.44}
# {'loss': 0.5067, 'learning_rate': 1.7068126520681268e-05, 'epoch': 0.44}
# {'loss': 0.499, 'learning_rate': 1.70529197080292e-05, 'epoch': 0.44}
# {'loss': 0.5268, 'learning_rate': 1.703771289537713e-05, 'epoch': 0.44}
# {'loss': 0.474, 'learning_rate': 1.7022506082725064e-05, 'epoch': 0.45}
# {'loss': 0.4898, 'learning_rate': 1.7007299270072995e-05, 'epoch': 0.45}
# {'loss': 0.4746, 'learning_rate': 1.6992092457420927e-05, 'epoch': 0.45}
# {'loss': 0.42, 'learning_rate': 1.6976885644768858e-05, 'epoch': 0.45}
# {'loss': 0.4843, 'learning_rate': 1.696167883211679e-05, 'epoch': 0.46}
# {'loss': 0.5269, 'learning_rate': 1.694647201946472e-05, 'epoch': 0.46}
# {'loss': 0.4735, 'learning_rate': 1.693126520681265e-05, 'epoch': 0.46}
# {'loss': 0.49, 'learning_rate': 1.6916058394160586e-05, 'epoch': 0.46}
# {'loss': 0.4799, 'learning_rate': 1.6900851581508517e-05, 'epoch': 0.47}
# {'loss': 0.4569, 'learning_rate': 1.6885644768856448e-05, 'epoch': 0.47}
# {'loss': 0.5159, 'learning_rate': 1.6870437956204383e-05, 'epoch': 0.47}
# {'loss': 0.5144, 'learning_rate': 1.6855231143552314e-05, 'epoch': 0.47}
# {'loss': 0.5226, 'learning_rate': 1.6840024330900245e-05, 'epoch': 0.47}
# {'loss': 0.5028, 'learning_rate': 1.6824817518248176e-05, 'epoch': 0.48}
# {'loss': 0.4715, 'learning_rate': 1.6809610705596107e-05, 'epoch': 0.48}
# {'loss': 0.5024, 'learning_rate': 1.6794403892944042e-05, 'epoch': 0.48}
# {'loss': 0.4831, 'learning_rate': 1.6779197080291973e-05, 'epoch': 0.48}
# {'loss': 0.4455, 'learning_rate': 1.6763990267639904e-05, 'epoch': 0.49}
# {'loss': 0.5164, 'learning_rate': 1.6748783454987835e-05, 'epoch': 0.49}
# {'loss': 0.458, 'learning_rate': 1.6733576642335766e-05, 'epoch': 0.49}
# {'loss': 0.4609, 'learning_rate': 1.67183698296837e-05, 'epoch': 0.49}
# {'loss': 0.4882, 'learning_rate': 1.6703163017031632e-05, 'epoch': 0.49}
# {'loss': 0.4731, 'learning_rate': 1.6687956204379563e-05, 'epoch': 0.5}
# {'loss': 0.4605, 'learning_rate': 1.6672749391727498e-05, 'epoch': 0.5}
# {'loss': 0.4346, 'learning_rate': 1.665754257907543e-05, 'epoch': 0.5}
# {'loss': 0.5117, 'learning_rate': 1.664233576642336e-05, 'epoch': 0.5}
# {'loss': 0.4675, 'learning_rate': 1.662712895377129e-05, 'epoch': 0.51}
# {'loss': 0.4972, 'learning_rate': 1.6611922141119222e-05, 'epoch': 0.51}
# {'loss': 0.4488, 'learning_rate': 1.6596715328467153e-05, 'epoch': 0.51}
# {'loss': 0.4473, 'learning_rate': 1.6581508515815085e-05, 'epoch': 0.51}
# {'loss': 0.4595, 'learning_rate': 1.656630170316302e-05, 'epoch': 0.52}
# {'loss': 0.5321, 'learning_rate': 1.655109489051095e-05, 'epoch': 0.52}
# {'loss': 0.4106, 'learning_rate': 1.653588807785888e-05, 'epoch': 0.52}
# {'loss': 0.5337, 'learning_rate': 1.6520681265206816e-05, 'epoch': 0.52}
# {'loss': 0.4688, 'learning_rate': 1.6505474452554747e-05, 'epoch': 0.52}
# {'loss': 0.4684, 'learning_rate': 1.6490267639902678e-05, 'epoch': 0.53}
# {'loss': 0.4234, 'learning_rate': 1.647506082725061e-05, 'epoch': 0.53}
# {'loss': 0.468, 'learning_rate': 1.645985401459854e-05, 'epoch': 0.53}
# {'loss': 0.4837, 'learning_rate': 1.6444647201946472e-05, 'epoch': 0.53}
# {'loss': 0.4691, 'learning_rate': 1.6429440389294403e-05, 'epoch': 0.54}
# {'loss': 0.4983, 'learning_rate': 1.6414233576642337e-05, 'epoch': 0.54}
# {'loss': 0.4774, 'learning_rate': 1.639902676399027e-05, 'epoch': 0.54}
# {'loss': 0.5444, 'learning_rate': 1.63838199513382e-05, 'epoch': 0.54}
# {'loss': 0.471, 'learning_rate': 1.6368613138686134e-05, 'epoch': 0.55}
# {'loss': 0.5513, 'learning_rate': 1.6353406326034065e-05, 'epoch': 0.55}
# {'loss': 0.4197, 'learning_rate': 1.6338199513381997e-05, 'epoch': 0.55}
# {'loss': 0.4966, 'learning_rate': 1.6322992700729928e-05, 'epoch': 0.55}
# {'loss': 0.4905, 'learning_rate': 1.6307785888077862e-05, 'epoch': 0.55}
# {'loss': 0.5192, 'learning_rate': 1.6292579075425793e-05, 'epoch': 0.56}
# {'loss': 0.4789, 'learning_rate': 1.627889294403893e-05, 'epoch': 0.56}
# {'loss': 0.4685, 'learning_rate': 1.626368613138686e-05, 'epoch': 0.56}
# {'loss': 0.4595, 'learning_rate': 1.6248479318734796e-05, 'epoch': 0.56}
# {'loss': 0.4953, 'learning_rate': 1.6233272506082727e-05, 'epoch': 0.57}
# {'loss': 0.4812, 'learning_rate': 1.621806569343066e-05, 'epoch': 0.57}
# {'loss': 0.5083, 'learning_rate': 1.620285888077859e-05, 'epoch': 0.57}
# {'loss': 0.5004, 'learning_rate': 1.6187652068126524e-05, 'epoch': 0.57}
# {'loss': 0.4702, 'learning_rate': 1.6172445255474455e-05, 'epoch': 0.57}
# {'loss': 0.4702, 'learning_rate': 1.6157238442822386e-05, 'epoch': 0.58}
# {'loss': 0.4912, 'learning_rate': 1.6142031630170318e-05, 'epoch': 0.58}
# {'loss': 0.5178, 'learning_rate': 1.612682481751825e-05, 'epoch': 0.58}
# {'loss': 0.4497, 'learning_rate': 1.611161800486618e-05, 'epoch': 0.58}
# {'loss': 0.5115, 'learning_rate': 1.6096411192214114e-05, 'epoch': 0.59}
# {'loss': 0.5064, 'learning_rate': 1.6081204379562046e-05, 'epoch': 0.59}
# {'loss': 0.5014, 'learning_rate': 1.6065997566909977e-05, 'epoch': 0.59}
# {'loss': 0.5118, 'learning_rate': 1.6050790754257908e-05, 'epoch': 0.59}
# {'loss': 0.431, 'learning_rate': 1.6035583941605842e-05, 'epoch': 0.6}
# {'loss': 0.4761, 'learning_rate': 1.6020377128953774e-05, 'epoch': 0.6}
# {'loss': 0.4225, 'learning_rate': 1.6005170316301705e-05, 'epoch': 0.6}
# {'loss': 0.5453, 'learning_rate': 1.5989963503649636e-05, 'epoch': 0.6}
# {'loss': 0.4515, 'learning_rate': 1.5974756690997567e-05, 'epoch': 0.6}
# {'loss': 0.4855, 'learning_rate': 1.5959549878345498e-05, 'epoch': 0.61}
# {'loss': 0.4492, 'learning_rate': 1.5944343065693433e-05, 'epoch': 0.61}
# {'loss': 0.5411, 'learning_rate': 1.5929136253041364e-05, 'epoch': 0.61}
# {'loss': 0.4447, 'learning_rate': 1.5913929440389295e-05, 'epoch': 0.61}
# {'loss': 0.476, 'learning_rate': 1.589872262773723e-05, 'epoch': 0.62}
# {'loss': 0.4702, 'learning_rate': 1.588351581508516e-05, 'epoch': 0.62}
# {'loss': 0.4514, 'learning_rate': 1.5868309002433092e-05, 'epoch': 0.62}
# {'loss': 0.5227, 'learning_rate': 1.5853102189781023e-05, 'epoch': 0.62}
# {'loss': 0.4985, 'learning_rate': 1.5837895377128954e-05, 'epoch': 0.62}
# {'loss': 0.4236, 'learning_rate': 1.5822688564476885e-05, 'epoch': 0.63}
# {'loss': 0.4854, 'learning_rate': 1.5807481751824816e-05, 'epoch': 0.63}
# {'loss': 0.4683, 'learning_rate': 1.579227493917275e-05, 'epoch': 0.63}
# {'loss': 0.4637, 'learning_rate': 1.5777068126520682e-05, 'epoch': 0.63}
# {'loss': 0.4814, 'learning_rate': 1.5761861313868613e-05, 'epoch': 0.64}
# {'loss': 0.5109, 'learning_rate': 1.5746654501216548e-05, 'epoch': 0.64}
# {'loss': 0.4451, 'learning_rate': 1.573144768856448e-05, 'epoch': 0.64}
# {'loss': 0.4685, 'learning_rate': 1.571624087591241e-05, 'epoch': 0.64}
# {'loss': 0.5016, 'learning_rate': 1.570103406326034e-05, 'epoch': 0.65}
# {'loss': 0.5102, 'learning_rate': 1.5685827250608276e-05, 'epoch': 0.65}
# {'loss': 0.5271, 'learning_rate': 1.5670620437956207e-05, 'epoch': 0.65}
# {'loss': 0.5162, 'learning_rate': 1.5655413625304138e-05, 'epoch': 0.65}
# {'loss': 0.4784, 'learning_rate': 1.564020681265207e-05, 'epoch': 0.65}
# {'loss': 0.4795, 'learning_rate': 1.5625e-05, 'epoch': 0.66}
# {'loss': 0.4688, 'learning_rate': 1.560979318734793e-05, 'epoch': 0.66}
# {'loss': 0.4363, 'learning_rate': 1.5594586374695866e-05, 'epoch': 0.66}
# {'loss': 0.4691, 'learning_rate': 1.5579379562043797e-05, 'epoch': 0.66}
# {'loss': 0.4482, 'learning_rate': 1.556417274939173e-05, 'epoch': 0.67}
# {'loss': 0.5093, 'learning_rate': 1.5548965936739663e-05, 'epoch': 0.67}
# {'loss': 0.4433, 'learning_rate': 1.5533759124087594e-05, 'epoch': 0.67}
# {'loss': 0.4444, 'learning_rate': 1.5518552311435525e-05, 'epoch': 0.67}
# {'loss': 0.4792, 'learning_rate': 1.5503345498783456e-05, 'epoch': 0.68}
# {'loss': 0.4813, 'learning_rate': 1.5488138686131387e-05, 'epoch': 0.68}
# {'loss': 0.474, 'learning_rate': 1.547293187347932e-05, 'epoch': 0.68}
# {'loss': 0.484, 'learning_rate': 1.545772506082725e-05, 'epoch': 0.68}
# {'loss': 0.4522, 'learning_rate': 1.5442518248175184e-05, 'epoch': 0.68}
# {'loss': 0.4358, 'learning_rate': 1.5427311435523115e-05, 'epoch': 0.69}
# {'loss': 0.4076, 'learning_rate': 1.5412104622871047e-05, 'epoch': 0.69}
# {'loss': 0.4968, 'learning_rate': 1.539689781021898e-05, 'epoch': 0.69}
# {'loss': 0.455, 'learning_rate': 1.5381690997566912e-05, 'epoch': 0.69}
# {'loss': 0.4525, 'learning_rate': 1.5366484184914843e-05, 'epoch': 0.7}
# {'loss': 0.4631, 'learning_rate': 1.5351277372262775e-05, 'epoch': 0.7}
# {'loss': 0.5176, 'learning_rate': 1.5336070559610706e-05, 'epoch': 0.7}
# {'loss': 0.4287, 'learning_rate': 1.5320863746958637e-05, 'epoch': 0.7}
# {'loss': 0.4833, 'learning_rate': 1.530565693430657e-05, 'epoch': 0.7}
# {'loss': 0.4985, 'learning_rate': 1.5290450121654503e-05, 'epoch': 0.71}
# {'loss': 0.4361, 'learning_rate': 1.5275243309002434e-05, 'epoch': 0.71}
# {'loss': 0.4848, 'learning_rate': 1.5260036496350365e-05, 'epoch': 0.71}
# {'loss': 0.4631, 'learning_rate': 1.52448296836983e-05, 'epoch': 0.71}
# {'loss': 0.4274, 'learning_rate': 1.522962287104623e-05, 'epoch': 0.72}
# {'loss': 0.4609, 'learning_rate': 1.5214416058394162e-05, 'epoch': 0.72}
# {'loss': 0.4284, 'learning_rate': 1.5199209245742095e-05, 'epoch': 0.72}
# {'loss': 0.4652, 'learning_rate': 1.5184002433090026e-05, 'epoch': 0.72}
# {'loss': 0.4634, 'learning_rate': 1.5168795620437957e-05, 'epoch': 0.73}
# {'loss': 0.4813, 'learning_rate': 1.5153588807785888e-05, 'epoch': 0.73}
# {'loss': 0.4377, 'learning_rate': 1.5138381995133823e-05, 'epoch': 0.73}
# {'loss': 0.4978, 'learning_rate': 1.5123175182481754e-05, 'epoch': 0.73}
# {'loss': 0.4589, 'learning_rate': 1.5107968369829685e-05, 'epoch': 0.73}
# {'loss': 0.4731, 'learning_rate': 1.5092761557177618e-05, 'epoch': 0.74}
# {'loss': 0.465, 'learning_rate': 1.5077554744525549e-05, 'epoch': 0.74}
# {'loss': 0.4207, 'learning_rate': 1.506234793187348e-05, 'epoch': 0.74}
# {'loss': 0.4589, 'learning_rate': 1.5047141119221413e-05, 'epoch': 0.74}
# {'loss': 0.3746, 'learning_rate': 1.5031934306569344e-05, 'epoch': 0.75}
# {'loss': 0.5339, 'learning_rate': 1.5016727493917275e-05, 'epoch': 0.75}
# {'loss': 0.4736, 'learning_rate': 1.5001520681265206e-05, 'epoch': 0.75}
# {'loss': 0.4828, 'learning_rate': 1.498631386861314e-05, 'epoch': 0.75}
# {'loss': 0.4102, 'learning_rate': 1.4971107055961072e-05, 'epoch': 0.76}
# {'loss': 0.4165, 'learning_rate': 1.4955900243309003e-05, 'epoch': 0.76}
# {'loss': 0.4411, 'learning_rate': 1.4940693430656936e-05, 'epoch': 0.76}
# {'loss': 0.4307, 'learning_rate': 1.4925486618004867e-05, 'epoch': 0.76}
# {'loss': 0.4118, 'learning_rate': 1.4910279805352798e-05, 'epoch': 0.76}
# {'loss': 0.4083, 'learning_rate': 1.4895072992700733e-05, 'epoch': 0.77}
# {'loss': 0.4471, 'learning_rate': 1.4879866180048664e-05, 'epoch': 0.77}
# {'loss': 0.4352, 'learning_rate': 1.4864659367396595e-05, 'epoch': 0.77}
# {'loss': 0.3897, 'learning_rate': 1.4849452554744528e-05, 'epoch': 0.77}
# {'loss': 0.419, 'learning_rate': 1.4834245742092459e-05, 'epoch': 0.78}
# {'loss': 0.4719, 'learning_rate': 1.481903892944039e-05, 'epoch': 0.78}
# {'loss': 0.4895, 'learning_rate': 1.4803832116788321e-05, 'epoch': 0.78}
# {'loss': 0.4707, 'learning_rate': 1.4788625304136254e-05, 'epoch': 0.78}
# {'loss': 0.4874, 'learning_rate': 1.4773418491484185e-05, 'epoch': 0.78}
# {'loss': 0.438, 'learning_rate': 1.4758211678832116e-05, 'epoch': 0.79}
# {'loss': 0.4515, 'learning_rate': 1.4743004866180051e-05, 'epoch': 0.79}
# {'loss': 0.4751, 'learning_rate': 1.4727798053527982e-05, 'epoch': 0.79}
# {'loss': 0.5085, 'learning_rate': 1.4712591240875913e-05, 'epoch': 0.79}
# {'loss': 0.4894, 'learning_rate': 1.4697384428223846e-05, 'epoch': 0.8}
# {'loss': 0.4428, 'learning_rate': 1.4682177615571777e-05, 'epoch': 0.8}
# {'loss': 0.5044, 'learning_rate': 1.4666970802919708e-05, 'epoch': 0.8}
# {'loss': 0.4245, 'learning_rate': 1.465176399026764e-05, 'epoch': 0.8}
# {'loss': 0.4342, 'learning_rate': 1.4636557177615574e-05, 'epoch': 0.81}
# {'loss': 0.4491, 'learning_rate': 1.4621350364963505e-05, 'epoch': 0.81}
# {'loss': 0.4545, 'learning_rate': 1.4606143552311436e-05, 'epoch': 0.81}
# {'loss': 0.4089, 'learning_rate': 1.459093673965937e-05, 'epoch': 0.81}
# {'loss': 0.4931, 'learning_rate': 1.45757299270073e-05, 'epoch': 0.81}
# {'loss': 0.4379, 'learning_rate': 1.4560523114355232e-05, 'epoch': 0.82}
# {'loss': 0.4467, 'learning_rate': 1.4545316301703164e-05, 'epoch': 0.82}
# {'loss': 0.4248, 'learning_rate': 1.4530109489051096e-05, 'epoch': 0.82}
# {'loss': 0.4072, 'learning_rate': 1.4514902676399027e-05, 'epoch': 0.82}
# {'loss': 0.4515, 'learning_rate': 1.4499695863746961e-05, 'epoch': 0.83}
# {'loss': 0.4513, 'learning_rate': 1.4484489051094892e-05, 'epoch': 0.83}
# {'loss': 0.4381, 'learning_rate': 1.4469282238442824e-05, 'epoch': 0.83}
# {'loss': 0.4085, 'learning_rate': 1.4454075425790755e-05, 'epoch': 0.83}
# {'loss': 0.4753, 'learning_rate': 1.4438868613138688e-05, 'epoch': 0.83}
# {'loss': 0.4714, 'learning_rate': 1.4423661800486619e-05, 'epoch': 0.84}
# {'loss': 0.4032, 'learning_rate': 1.440845498783455e-05, 'epoch': 0.84}
# {'loss': 0.4891, 'learning_rate': 1.4393248175182484e-05, 'epoch': 0.84}
# {'loss': 0.4102, 'learning_rate': 1.4378041362530416e-05, 'epoch': 0.84}
# {'loss': 0.4539, 'learning_rate': 1.4362834549878347e-05, 'epoch': 0.85}
# {'loss': 0.4259, 'learning_rate': 1.434762773722628e-05, 'epoch': 0.85}
# {'loss': 0.4853, 'learning_rate': 1.433242092457421e-05, 'epoch': 0.85}
# {'loss': 0.459, 'learning_rate': 1.4317214111922142e-05, 'epoch': 0.85}
# {'loss': 0.4654, 'learning_rate': 1.4302007299270073e-05, 'epoch': 0.86}
# {'loss': 0.4076, 'learning_rate': 1.4286800486618006e-05, 'epoch': 0.86}
# {'loss': 0.4351, 'learning_rate': 1.4271593673965937e-05, 'epoch': 0.86}
# {'loss': 0.5102, 'learning_rate': 1.4256386861313868e-05, 'epoch': 0.86}
# {'loss': 0.4568, 'learning_rate': 1.4241180048661803e-05, 'epoch': 0.86}
# {'loss': 0.4302, 'learning_rate': 1.4225973236009734e-05, 'epoch': 0.87}
# {'loss': 0.4248, 'learning_rate': 1.4210766423357665e-05, 'epoch': 0.87}
# {'loss': 0.4449, 'learning_rate': 1.4195559610705598e-05, 'epoch': 0.87}
# {'loss': 0.4355, 'learning_rate': 1.4180352798053529e-05, 'epoch': 0.87}
# {'loss': 0.4599, 'learning_rate': 1.416514598540146e-05, 'epoch': 0.88}
# {'loss': 0.4609, 'learning_rate': 1.4149939172749395e-05, 'epoch': 0.88}
# {'loss': 0.4515, 'learning_rate': 1.4134732360097326e-05, 'epoch': 0.88}
# {'loss': 0.4576, 'learning_rate': 1.4119525547445257e-05, 'epoch': 0.88}
# {'loss': 0.4245, 'learning_rate': 1.4104318734793188e-05, 'epoch': 0.89}
# {'loss': 0.4323, 'learning_rate': 1.4089111922141121e-05, 'epoch': 0.89}
# {'loss': 0.4249, 'learning_rate': 1.4073905109489052e-05, 'epoch': 0.89}
# {'loss': 0.4695, 'learning_rate': 1.4058698296836983e-05, 'epoch': 0.89}
# {'loss': 0.4038, 'learning_rate': 1.4043491484184916e-05, 'epoch': 0.89}
# {'loss': 0.4602, 'learning_rate': 1.4028284671532847e-05, 'epoch': 0.9}
# {'loss': 0.4183, 'learning_rate': 1.4013077858880778e-05, 'epoch': 0.9}
# {'loss': 0.4548, 'learning_rate': 1.3997871046228713e-05, 'epoch': 0.9}
# {'loss': 0.4354, 'learning_rate': 1.3982664233576644e-05, 'epoch': 0.9}
# {'loss': 0.4478, 'learning_rate': 1.3967457420924575e-05, 'epoch': 0.91}
# {'loss': 0.4565, 'learning_rate': 1.3952250608272506e-05, 'epoch': 0.91}
# {'loss': 0.4774, 'learning_rate': 1.393704379562044e-05, 'epoch': 0.91}
# {'loss': 0.439, 'learning_rate': 1.392183698296837e-05, 'epoch': 0.91}
# {'loss': 0.4386, 'learning_rate': 1.3906630170316302e-05, 'epoch': 0.91}
# {'loss': 0.4474, 'learning_rate': 1.3891423357664236e-05, 'epoch': 0.92}
# {'loss': 0.4651, 'learning_rate': 1.3876216545012167e-05, 'epoch': 0.92}
# {'loss': 0.4656, 'learning_rate': 1.3861009732360098e-05, 'epoch': 0.92}
# {'loss': 0.4445, 'learning_rate': 1.3845802919708031e-05, 'epoch': 0.92}
# {'loss': 0.4633, 'learning_rate': 1.3830596107055962e-05, 'epoch': 0.93}
# {'loss': 0.443, 'learning_rate': 1.3815389294403893e-05, 'epoch': 0.93}
# {'loss': 0.4295, 'learning_rate': 1.3800182481751825e-05, 'epoch': 0.93}
# {'loss': 0.4769, 'learning_rate': 1.3784975669099757e-05, 'epoch': 0.93}
# {'loss': 0.3939, 'learning_rate': 1.3769768856447689e-05, 'epoch': 0.94}
# {'loss': 0.4228, 'learning_rate': 1.3754562043795621e-05, 'epoch': 0.94}
# {'loss': 0.4223, 'learning_rate': 1.3739355231143554e-05, 'epoch': 0.94}
# {'loss': 0.4218, 'learning_rate': 1.3724148418491485e-05, 'epoch': 0.94}
# {'loss': 0.4264, 'learning_rate': 1.3708941605839417e-05, 'epoch': 0.94}
# {'loss': 0.4349, 'learning_rate': 1.369373479318735e-05, 'epoch': 0.95}
# {'loss': 0.4863, 'learning_rate': 1.367852798053528e-05, 'epoch': 0.95}
# {'loss': 0.4375, 'learning_rate': 1.3663321167883212e-05, 'epoch': 0.95}
# {'loss': 0.4514, 'learning_rate': 1.3648114355231146e-05, 'epoch': 0.95}
# {'loss': 0.4468, 'learning_rate': 1.3632907542579077e-05, 'epoch': 0.96}
# {'loss': 0.4807, 'learning_rate': 1.3617700729927009e-05, 'epoch': 0.96}
# {'loss': 0.4668, 'learning_rate': 1.360249391727494e-05, 'epoch': 0.96}
# {'loss': 0.4729, 'learning_rate': 1.3587287104622873e-05, 'epoch': 0.96}
# {'loss': 0.4268, 'learning_rate': 1.3572080291970804e-05, 'epoch': 0.96}
# {'loss': 0.4207, 'learning_rate': 1.3556873479318735e-05, 'epoch': 0.97}
# {'loss': 0.4391, 'learning_rate': 1.3541666666666668e-05, 'epoch': 0.97}
# {'loss': 0.369, 'learning_rate': 1.3526459854014599e-05, 'epoch': 0.97}
# {'loss': 0.476, 'learning_rate': 1.3511253041362532e-05, 'epoch': 0.97}
# {'loss': 0.3834, 'learning_rate': 1.3496046228710465e-05, 'epoch': 0.98}
# {'loss': 0.4539, 'learning_rate': 1.3480839416058396e-05, 'epoch': 0.98}
# {'loss': 0.4227, 'learning_rate': 1.3465632603406327e-05, 'epoch': 0.98}
# {'loss': 0.4377, 'learning_rate': 1.3450425790754258e-05, 'epoch': 0.98}
# {'loss': 0.4306, 'learning_rate': 1.3435218978102191e-05, 'epoch': 0.99}
# {'loss': 0.3846, 'learning_rate': 1.3420012165450122e-05, 'epoch': 0.99}
# {'loss': 0.4488, 'learning_rate': 1.3404805352798053e-05, 'epoch': 0.99}
# {'loss': 0.4119, 'learning_rate': 1.3389598540145988e-05, 'epoch': 0.99}
# {'loss': 0.4853, 'learning_rate': 1.3374391727493919e-05, 'epoch': 0.99}
# {'loss': 0.4532, 'learning_rate': 1.335918491484185e-05, 'epoch': 1.0}
# {'loss': 0.4516, 'learning_rate': 1.3343978102189783e-05, 'epoch': 1.0}
#   0%|          | 0/488 [00:00<?, ?it/s]
# {'eval_loss': 0.39518237113952637, 'eval_runtime': 41.3294, 'eval_samples_per_second': 188.558, 'eval_steps_per_second': 11.808, 'epoch': 1.0}
# {'loss': 0.4515, 'learning_rate': 1.3328771289537714e-05, 'epoch': 1.0}
# {'loss': 0.4518, 'learning_rate': 1.3313564476885645e-05, 'epoch': 1.0}
# {'loss': 0.4151, 'learning_rate': 1.3298357664233578e-05, 'epoch': 1.01}
# {'loss': 0.4643, 'learning_rate': 1.3283150851581509e-05, 'epoch': 1.01}
# {'loss': 0.4429, 'learning_rate': 1.3267944038929442e-05, 'epoch': 1.01}
# {'loss': 0.435, 'learning_rate': 1.3252737226277373e-05, 'epoch': 1.01}
# {'loss': 0.3448, 'learning_rate': 1.3237530413625306e-05, 'epoch': 1.02}
# {'loss': 0.4345, 'learning_rate': 1.3222323600973237e-05, 'epoch': 1.02}
# {'loss': 0.4091, 'learning_rate': 1.3207116788321168e-05, 'epoch': 1.02}
# {'loss': 0.403, 'learning_rate': 1.3191909975669101e-05, 'epoch': 1.02}
# {'loss': 0.4413, 'learning_rate': 1.3176703163017032e-05, 'epoch': 1.02}
# {'loss': 0.4783, 'learning_rate': 1.3161496350364963e-05, 'epoch': 1.03}
# {'loss': 0.4873, 'learning_rate': 1.3146289537712898e-05, 'epoch': 1.03}
# {'loss': 0.4545, 'learning_rate': 1.3131082725060829e-05, 'epoch': 1.03}
# {'loss': 0.4671, 'learning_rate': 1.311587591240876e-05, 'epoch': 1.03}
# {'loss': 0.4046, 'learning_rate': 1.3100669099756691e-05, 'epoch': 1.04}
# {'loss': 0.4807, 'learning_rate': 1.3085462287104624e-05, 'epoch': 1.04}
# {'loss': 0.4742, 'learning_rate': 1.3070255474452555e-05, 'epoch': 1.04}
# {'loss': 0.4603, 'learning_rate': 1.3055048661800487e-05, 'epoch': 1.04}
# {'loss': 0.4236, 'learning_rate': 1.303984184914842e-05, 'epoch': 1.04}
# {'loss': 0.4409, 'learning_rate': 1.3024635036496352e-05, 'epoch': 1.05}
# {'loss': 0.4438, 'learning_rate': 1.3009428223844283e-05, 'epoch': 1.05}
# {'loss': 0.4622, 'learning_rate': 1.2994221411192216e-05, 'epoch': 1.05}
# {'loss': 0.4369, 'learning_rate': 1.2979014598540147e-05, 'epoch': 1.05}
# {'loss': 0.401, 'learning_rate': 1.2963807785888079e-05, 'epoch': 1.06}
# {'loss': 0.4756, 'learning_rate': 1.2948600973236011e-05, 'epoch': 1.06}
# {'loss': 0.4026, 'learning_rate': 1.2933394160583943e-05, 'epoch': 1.06}
# {'loss': 0.4335, 'learning_rate': 1.2918187347931874e-05, 'epoch': 1.06}
# {'loss': 0.4176, 'learning_rate': 1.2902980535279805e-05, 'epoch': 1.07}
# {'loss': 0.412, 'learning_rate': 1.288777372262774e-05, 'epoch': 1.07}
# {'loss': 0.3929, 'learning_rate': 1.287256690997567e-05, 'epoch': 1.07}
# {'loss': 0.4566, 'learning_rate': 1.2857360097323602e-05, 'epoch': 1.07}
# {'loss': 0.5111, 'learning_rate': 1.2842153284671534e-05, 'epoch': 1.07}
# {'loss': 0.4237, 'learning_rate': 1.2826946472019466e-05, 'epoch': 1.08}
# {'loss': 0.4576, 'learning_rate': 1.2811739659367397e-05, 'epoch': 1.08}
# {'loss': 0.4653, 'learning_rate': 1.279653284671533e-05, 'epoch': 1.08}
# {'loss': 0.4221, 'learning_rate': 1.2781326034063262e-05, 'epoch': 1.08}
# {'loss': 0.4554, 'learning_rate': 1.2766119221411194e-05, 'epoch': 1.09}
# {'loss': 0.4349, 'learning_rate': 1.2750912408759125e-05, 'epoch': 1.09}
# {'loss': 0.4101, 'learning_rate': 1.2735705596107058e-05, 'epoch': 1.09}
# {'loss': 0.4405, 'learning_rate': 1.2720498783454989e-05, 'epoch': 1.09}
# {'loss': 0.3809, 'learning_rate': 1.270529197080292e-05, 'epoch': 1.09}
# {'loss': 0.4116, 'learning_rate': 1.2690085158150853e-05, 'epoch': 1.1}
# {'loss': 0.4199, 'learning_rate': 1.2674878345498784e-05, 'epoch': 1.1}
# {'loss': 0.4333, 'learning_rate': 1.2659671532846715e-05, 'epoch': 1.1}
# {'loss': 0.4232, 'learning_rate': 1.264446472019465e-05, 'epoch': 1.1}
# {'loss': 0.4387, 'learning_rate': 1.262925790754258e-05, 'epoch': 1.11}
# {'loss': 0.412, 'learning_rate': 1.2614051094890512e-05, 'epoch': 1.11}
# {'loss': 0.3903, 'learning_rate': 1.2598844282238445e-05, 'epoch': 1.11}
# {'loss': 0.449, 'learning_rate': 1.2583637469586376e-05, 'epoch': 1.11}
# {'loss': 0.4935, 'learning_rate': 1.2568430656934307e-05, 'epoch': 1.12}
# {'loss': 0.4384, 'learning_rate': 1.2553223844282238e-05, 'epoch': 1.12}
# {'loss': 0.4251, 'learning_rate': 1.2538017031630173e-05, 'epoch': 1.12}
# {'loss': 0.4032, 'learning_rate': 1.2522810218978104e-05, 'epoch': 1.12}
# {'loss': 0.3807, 'learning_rate': 1.2507603406326035e-05, 'epoch': 1.12}
# {'loss': 0.4044, 'learning_rate': 1.2492396593673968e-05, 'epoch': 1.13}
# {'loss': 0.4348, 'learning_rate': 1.2477189781021899e-05, 'epoch': 1.13}
# {'loss': 0.4406, 'learning_rate': 1.246198296836983e-05, 'epoch': 1.13}
# {'loss': 0.4454, 'learning_rate': 1.2446776155717763e-05, 'epoch': 1.13}
# {'loss': 0.4679, 'learning_rate': 1.2431569343065694e-05, 'epoch': 1.14}
# {'loss': 0.4455, 'learning_rate': 1.2416362530413625e-05, 'epoch': 1.14}
# {'loss': 0.4094, 'learning_rate': 1.2401155717761556e-05, 'epoch': 1.14}
# {'loss': 0.4397, 'learning_rate': 1.2385948905109491e-05, 'epoch': 1.14}
# {'loss': 0.4394, 'learning_rate': 1.2370742092457422e-05, 'epoch': 1.15}
# {'loss': 0.4326, 'learning_rate': 1.2355535279805353e-05, 'epoch': 1.15}
# {'loss': 0.4236, 'learning_rate': 1.2340328467153286e-05, 'epoch': 1.15}
# {'loss': 0.4176, 'learning_rate': 1.2325121654501217e-05, 'epoch': 1.15}
# {'loss': 0.4079, 'learning_rate': 1.2309914841849148e-05, 'epoch': 1.15}
# {'loss': 0.4318, 'learning_rate': 1.2294708029197083e-05, 'epoch': 1.16}
# {'loss': 0.4196, 'learning_rate': 1.2279501216545014e-05, 'epoch': 1.16}
# {'loss': 0.4123, 'learning_rate': 1.2264294403892945e-05, 'epoch': 1.16}
# {'loss': 0.4101, 'learning_rate': 1.2249087591240878e-05, 'epoch': 1.16}
# {'loss': 0.4505, 'learning_rate': 1.223388077858881e-05, 'epoch': 1.17}
# {'loss': 0.4108, 'learning_rate': 1.221867396593674e-05, 'epoch': 1.17}
# {'loss': 0.4587, 'learning_rate': 1.2203467153284672e-05, 'epoch': 1.17}
# {'loss': 0.4698, 'learning_rate': 1.2188260340632604e-05, 'epoch': 1.17}
# {'loss': 0.4013, 'learning_rate': 1.2173053527980536e-05, 'epoch': 1.17}
# {'loss': 0.5078, 'learning_rate': 1.2157846715328467e-05, 'epoch': 1.18}
# {'loss': 0.4343, 'learning_rate': 1.2142639902676401e-05, 'epoch': 1.18}
# {'loss': 0.4182, 'learning_rate': 1.2127433090024332e-05, 'epoch': 1.18}
# {'loss': 0.4282, 'learning_rate': 1.2112226277372264e-05, 'epoch': 1.18}
# {'loss': 0.4527, 'learning_rate': 1.2097019464720196e-05, 'epoch': 1.19}
# {'loss': 0.422, 'learning_rate': 1.2081812652068128e-05, 'epoch': 1.19}
# {'loss': 0.4469, 'learning_rate': 1.2066605839416059e-05, 'epoch': 1.19}
# {'loss': 0.4853, 'learning_rate': 1.205139902676399e-05, 'epoch': 1.19}
# {'loss': 0.4154, 'learning_rate': 1.2036192214111924e-05, 'epoch': 1.2}
# {'loss': 0.4679, 'learning_rate': 1.2020985401459856e-05, 'epoch': 1.2}
# {'loss': 0.5363, 'learning_rate': 1.2005778588807787e-05, 'epoch': 1.2}
# {'loss': 0.4494, 'learning_rate': 1.199057177615572e-05, 'epoch': 1.2}
# {'loss': 0.4173, 'learning_rate': 1.197536496350365e-05, 'epoch': 1.2}
# {'loss': 0.4306, 'learning_rate': 1.1960158150851582e-05, 'epoch': 1.21}
# {'loss': 0.4183, 'learning_rate': 1.1944951338199515e-05, 'epoch': 1.21}
# {'loss': 0.4329, 'learning_rate': 1.1929744525547446e-05, 'epoch': 1.21}
# {'loss': 0.4256, 'learning_rate': 1.1914537712895377e-05, 'epoch': 1.21}
# {'loss': 0.3989, 'learning_rate': 1.1899330900243311e-05, 'epoch': 1.22}
# {'loss': 0.4713, 'learning_rate': 1.1884124087591243e-05, 'epoch': 1.22}
# {'loss': 0.4942, 'learning_rate': 1.1868917274939174e-05, 'epoch': 1.22}
# {'loss': 0.4298, 'learning_rate': 1.1853710462287105e-05, 'epoch': 1.22}
# {'loss': 0.3778, 'learning_rate': 1.1838503649635038e-05, 'epoch': 1.22}
# {'loss': 0.4438, 'learning_rate': 1.1823296836982969e-05, 'epoch': 1.23}
# {'loss': 0.4356, 'learning_rate': 1.18080900243309e-05, 'epoch': 1.23}
# {'loss': 0.4634, 'learning_rate': 1.1792883211678835e-05, 'epoch': 1.23}
# {'loss': 0.4467, 'learning_rate': 1.1777676399026766e-05, 'epoch': 1.23}
# {'loss': 0.4286, 'learning_rate': 1.1762469586374697e-05, 'epoch': 1.24}
# {'loss': 0.3934, 'learning_rate': 1.174726277372263e-05, 'epoch': 1.24}
# {'loss': 0.4561, 'learning_rate': 1.1732055961070561e-05, 'epoch': 1.24}
# {'loss': 0.4183, 'learning_rate': 1.1716849148418492e-05, 'epoch': 1.24}
# {'loss': 0.4565, 'learning_rate': 1.1701642335766423e-05, 'epoch': 1.25}
# {'loss': 0.4864, 'learning_rate': 1.1686435523114356e-05, 'epoch': 1.25}
# {'loss': 0.4354, 'learning_rate': 1.1671228710462287e-05, 'epoch': 1.25}
# {'loss': 0.4051, 'learning_rate': 1.1656021897810218e-05, 'epoch': 1.25}
# {'loss': 0.4471, 'learning_rate': 1.1640815085158153e-05, 'epoch': 1.25}
# {'loss': 0.4091, 'learning_rate': 1.1625608272506084e-05, 'epoch': 1.26}
# {'loss': 0.4591, 'learning_rate': 1.1610401459854015e-05, 'epoch': 1.26}
# {'loss': 0.4131, 'learning_rate': 1.1595194647201948e-05, 'epoch': 1.26}
# {'loss': 0.4291, 'learning_rate': 1.157998783454988e-05, 'epoch': 1.26}
# {'loss': 0.3898, 'learning_rate': 1.156478102189781e-05, 'epoch': 1.27}
# {'loss': 0.4036, 'learning_rate': 1.1549574209245745e-05, 'epoch': 1.27}
# {'loss': 0.3894, 'learning_rate': 1.1534367396593676e-05, 'epoch': 1.27}
# {'loss': 0.3996, 'learning_rate': 1.1519160583941607e-05, 'epoch': 1.27}
# {'loss': 0.4634, 'learning_rate': 1.1503953771289538e-05, 'epoch': 1.28}
# {'loss': 0.4845, 'learning_rate': 1.1488746958637471e-05, 'epoch': 1.28}
# {'loss': 0.4146, 'learning_rate': 1.1473540145985402e-05, 'epoch': 1.28}
# {'loss': 0.4507, 'learning_rate': 1.1458333333333333e-05, 'epoch': 1.28}
# {'loss': 0.4535, 'learning_rate': 1.1443126520681266e-05, 'epoch': 1.28}
# {'loss': 0.4376, 'learning_rate': 1.1427919708029197e-05, 'epoch': 1.29}
# {'loss': 0.4059, 'learning_rate': 1.1412712895377129e-05, 'epoch': 1.29}
# {'loss': 0.3997, 'learning_rate': 1.1397506082725063e-05, 'epoch': 1.29}
# {'loss': 0.4065, 'learning_rate': 1.1382299270072994e-05, 'epoch': 1.29}
# {'loss': 0.4508, 'learning_rate': 1.1367092457420925e-05, 'epoch': 1.3}
# {'loss': 0.3903, 'learning_rate': 1.1351885644768857e-05, 'epoch': 1.3}
# {'loss': 0.4302, 'learning_rate': 1.133667883211679e-05, 'epoch': 1.3}
# {'loss': 0.4024, 'learning_rate': 1.132147201946472e-05, 'epoch': 1.3}
# {'loss': 0.4488, 'learning_rate': 1.1306265206812652e-05, 'epoch': 1.3}
# {'loss': 0.4212, 'learning_rate': 1.1291058394160586e-05, 'epoch': 1.31}
# {'loss': 0.3782, 'learning_rate': 1.1275851581508517e-05, 'epoch': 1.31}
# {'loss': 0.4676, 'learning_rate': 1.1260644768856449e-05, 'epoch': 1.31}
# {'loss': 0.3937, 'learning_rate': 1.1245437956204381e-05, 'epoch': 1.31}
# {'loss': 0.4174, 'learning_rate': 1.1230231143552313e-05, 'epoch': 1.32}
# {'loss': 0.4019, 'learning_rate': 1.1215024330900244e-05, 'epoch': 1.32}
# {'loss': 0.372, 'learning_rate': 1.1199817518248177e-05, 'epoch': 1.32}
# {'loss': 0.4061, 'learning_rate': 1.1184610705596108e-05, 'epoch': 1.32}
# {'loss': 0.4243, 'learning_rate': 1.1169403892944039e-05, 'epoch': 1.33}
# {'loss': 0.4174, 'learning_rate': 1.115419708029197e-05, 'epoch': 1.33}
# {'loss': 0.404, 'learning_rate': 1.1138990267639905e-05, 'epoch': 1.33}
# {'loss': 0.4202, 'learning_rate': 1.1123783454987836e-05, 'epoch': 1.33}
# {'loss': 0.4385, 'learning_rate': 1.1108576642335767e-05, 'epoch': 1.33}
# {'loss': 0.3919, 'learning_rate': 1.10933698296837e-05, 'epoch': 1.34}
# {'loss': 0.4144, 'learning_rate': 1.107816301703163e-05, 'epoch': 1.34}
# {'loss': 0.4385, 'learning_rate': 1.1062956204379562e-05, 'epoch': 1.34}
# {'loss': 0.397, 'learning_rate': 1.1047749391727497e-05, 'epoch': 1.34}
# {'loss': 0.4374, 'learning_rate': 1.1032542579075428e-05, 'epoch': 1.35}
# {'loss': 0.4651, 'learning_rate': 1.1017335766423359e-05, 'epoch': 1.35}
# {'loss': 0.4126, 'learning_rate': 1.100212895377129e-05, 'epoch': 1.35}
# {'loss': 0.3807, 'learning_rate': 1.0986922141119223e-05, 'epoch': 1.35}
# {'loss': 0.4131, 'learning_rate': 1.0971715328467154e-05, 'epoch': 1.35}
# {'loss': 0.4472, 'learning_rate': 1.0956508515815085e-05, 'epoch': 1.36}
# {'loss': 0.432, 'learning_rate': 1.0941301703163018e-05, 'epoch': 1.36}
# {'loss': 0.4235, 'learning_rate': 1.0926094890510949e-05, 'epoch': 1.36}
# {'loss': 0.4557, 'learning_rate': 1.091088807785888e-05, 'epoch': 1.36}
# {'loss': 0.4683, 'learning_rate': 1.0895681265206815e-05, 'epoch': 1.37}
# {'loss': 0.4429, 'learning_rate': 1.0880474452554746e-05, 'epoch': 1.37}
# {'loss': 0.4452, 'learning_rate': 1.0865267639902677e-05, 'epoch': 1.37}
# {'loss': 0.4336, 'learning_rate': 1.0850060827250608e-05, 'epoch': 1.37}
# {'loss': 0.4306, 'learning_rate': 1.0834854014598541e-05, 'epoch': 1.38}
# {'loss': 0.4048, 'learning_rate': 1.0819647201946472e-05, 'epoch': 1.38}
# {'loss': 0.3848, 'learning_rate': 1.0804440389294403e-05, 'epoch': 1.38}
# {'loss': 0.4061, 'learning_rate': 1.0789233576642338e-05, 'epoch': 1.38}
# {'loss': 0.3946, 'learning_rate': 1.0774026763990269e-05, 'epoch': 1.38}
# {'loss': 0.4015, 'learning_rate': 1.07588199513382e-05, 'epoch': 1.39}
# {'loss': 0.4636, 'learning_rate': 1.0743613138686133e-05, 'epoch': 1.39}
# {'loss': 0.4268, 'learning_rate': 1.0728406326034064e-05, 'epoch': 1.39}
# {'loss': 0.4436, 'learning_rate': 1.0713199513381995e-05, 'epoch': 1.39}
# {'loss': 0.3699, 'learning_rate': 1.0697992700729928e-05, 'epoch': 1.4}
# {'loss': 0.4694, 'learning_rate': 1.068278588807786e-05, 'epoch': 1.4}
# {'loss': 0.3967, 'learning_rate': 1.066757907542579e-05, 'epoch': 1.4}
# {'loss': 0.41, 'learning_rate': 1.0652372262773723e-05, 'epoch': 1.4}
# {'loss': 0.4295, 'learning_rate': 1.0637165450121656e-05, 'epoch': 1.41}
# {'loss': 0.3696, 'learning_rate': 1.0621958637469587e-05, 'epoch': 1.41}
# {'loss': 0.3472, 'learning_rate': 1.0606751824817518e-05, 'epoch': 1.41}
# {'loss': 0.4376, 'learning_rate': 1.0591545012165451e-05, 'epoch': 1.41}
# {'loss': 0.4236, 'learning_rate': 1.0576338199513382e-05, 'epoch': 1.41}
# {'loss': 0.4016, 'learning_rate': 1.0561131386861314e-05, 'epoch': 1.42}
# {'loss': 0.4362, 'learning_rate': 1.0545924574209248e-05, 'epoch': 1.42}
# {'loss': 0.4123, 'learning_rate': 1.053071776155718e-05, 'epoch': 1.42}
# {'loss': 0.5069, 'learning_rate': 1.051551094890511e-05, 'epoch': 1.42}
# {'loss': 0.4252, 'learning_rate': 1.0500304136253042e-05, 'epoch': 1.43}
# {'loss': 0.4338, 'learning_rate': 1.0485097323600974e-05, 'epoch': 1.43}
# {'loss': 0.4188, 'learning_rate': 1.0469890510948906e-05, 'epoch': 1.43}
# {'loss': 0.4322, 'learning_rate': 1.0454683698296837e-05, 'epoch': 1.43}
# {'loss': 0.3709, 'learning_rate': 1.043947688564477e-05, 'epoch': 1.43}
# {'loss': 0.4171, 'learning_rate': 1.04242700729927e-05, 'epoch': 1.44}
# {'loss': 0.4568, 'learning_rate': 1.0409063260340634e-05, 'epoch': 1.44}
# {'loss': 0.4491, 'learning_rate': 1.0393856447688566e-05, 'epoch': 1.44}
# {'loss': 0.4109, 'learning_rate': 1.0378649635036498e-05, 'epoch': 1.44}
# {'loss': 0.4078, 'learning_rate': 1.0363442822384429e-05, 'epoch': 1.45}
# {'loss': 0.4507, 'learning_rate': 1.0348236009732362e-05, 'epoch': 1.45}
# {'loss': 0.4015, 'learning_rate': 1.0333029197080293e-05, 'epoch': 1.45}
# {'loss': 0.4173, 'learning_rate': 1.0317822384428224e-05, 'epoch': 1.45}
# {'loss': 0.4491, 'learning_rate': 1.0302615571776155e-05, 'epoch': 1.46}
# {'loss': 0.4374, 'learning_rate': 1.028740875912409e-05, 'epoch': 1.46}
# {'loss': 0.5101, 'learning_rate': 1.027220194647202e-05, 'epoch': 1.46}
# {'loss': 0.4443, 'learning_rate': 1.0256995133819952e-05, 'epoch': 1.46}
# {'loss': 0.4394, 'learning_rate': 1.0241788321167885e-05, 'epoch': 1.46}
# {'loss': 0.4031, 'learning_rate': 1.0226581508515816e-05, 'epoch': 1.47}
# {'loss': 0.4005, 'learning_rate': 1.0211374695863747e-05, 'epoch': 1.47}
# {'loss': 0.4482, 'learning_rate': 1.019616788321168e-05, 'epoch': 1.47}
# {'loss': 0.4731, 'learning_rate': 1.0180961070559611e-05, 'epoch': 1.47}
# {'loss': 0.3978, 'learning_rate': 1.0165754257907544e-05, 'epoch': 1.48}
# {'loss': 0.4107, 'learning_rate': 1.0150547445255475e-05, 'epoch': 1.48}
# {'loss': 0.4304, 'learning_rate': 1.0135340632603408e-05, 'epoch': 1.48}
# {'loss': 0.4521, 'learning_rate': 1.0120133819951339e-05, 'epoch': 1.48}
# {'loss': 0.4077, 'learning_rate': 1.010492700729927e-05, 'epoch': 1.48}
# {'loss': 0.409, 'learning_rate': 1.0089720194647203e-05, 'epoch': 1.49}
# {'loss': 0.4636, 'learning_rate': 1.0074513381995134e-05, 'epoch': 1.49}
# {'loss': 0.4142, 'learning_rate': 1.0059306569343065e-05, 'epoch': 1.49}
# {'loss': 0.4449, 'learning_rate': 1.0044099756691e-05, 'epoch': 1.49}
# {'loss': 0.3875, 'learning_rate': 1.0028892944038931e-05, 'epoch': 1.5}
# {'loss': 0.4402, 'learning_rate': 1.0013686131386862e-05, 'epoch': 1.5}
# {'loss': 0.4164, 'learning_rate': 9.998479318734793e-06, 'epoch': 1.5}
# ...
# {'loss': 0.4483, 'learning_rate': 3.2329683698296837e-06, 'epoch': 2.52}
# {'loss': 0.3871, 'learning_rate': 3.217761557177616e-06, 'epoch': 2.52}
# {'loss': 0.3991, 'learning_rate': 3.2025547445255477e-06, 'epoch': 2.52}
# {'loss': 0.4074, 'learning_rate': 3.1873479318734797e-06, 'epoch': 2.52}
# {'loss': 0.4485, 'learning_rate': 3.1721411192214113e-06, 'epoch': 2.53}
# {'loss': 0.3889, 'learning_rate': 3.156934306569343e-06, 'epoch': 2.53}
# {'loss': 0.4426, 'learning_rate': 3.1417274939172753e-06, 'epoch': 2.53}
# {'loss': 0.4628, 'learning_rate': 3.1265206812652073e-06, 'epoch': 2.53}
# {'loss': 0.3823, 'learning_rate': 3.111313868613139e-06, 'epoch': 2.53}
# {'loss': 0.4441, 'learning_rate': 3.0961070559610704e-06, 'epoch': 2.54}
# {'loss': 0.4548, 'learning_rate': 3.080900243309003e-06, 'epoch': 2.54}
# {'loss': 0.459, 'learning_rate': 3.065693430656935e-06, 'epoch': 2.54}
# {'loss': 0.4393, 'learning_rate': 3.0504866180048664e-06, 'epoch': 2.54}
# {'loss': 0.4341, 'learning_rate': 3.035279805352798e-06, 'epoch': 2.55}
# {'loss': 0.4289, 'learning_rate': 3.02007299270073e-06, 'epoch': 2.55}
# {'loss': 0.3663, 'learning_rate': 3.0048661800486624e-06, 'epoch': 2.55}
# {'loss': 0.3987, 'learning_rate': 2.989659367396594e-06, 'epoch': 2.55}
# {'loss': 0.4184, 'learning_rate': 2.9744525547445256e-06, 'epoch': 2.55}
# {'loss': 0.4487, 'learning_rate': 2.9592457420924576e-06, 'epoch': 2.56}
# {'loss': 0.4321, 'learning_rate': 2.944038929440389e-06, 'epoch': 2.56}
# {'loss': 0.3832, 'learning_rate': 2.9288321167883215e-06, 'epoch': 2.56}
# {'loss': 0.4525, 'learning_rate': 2.913625304136253e-06, 'epoch': 2.56}
# {'loss': 0.3844, 'learning_rate': 2.898418491484185e-06, 'epoch': 2.57}
# {'loss': 0.3696, 'learning_rate': 2.8832116788321167e-06, 'epoch': 2.57}
# {'loss': 0.3929, 'learning_rate': 2.868004866180049e-06, 'epoch': 2.57}
# {'loss': 0.4061, 'learning_rate': 2.8527980535279807e-06, 'epoch': 2.57}
# {'loss': 0.4401, 'learning_rate': 2.8375912408759127e-06, 'epoch': 2.58}
# {'loss': 0.3908, 'learning_rate': 2.8223844282238443e-06, 'epoch': 2.58}
# {'loss': 0.4474, 'learning_rate': 2.8071776155717762e-06, 'epoch': 2.58}
# {'loss': 0.3965, 'learning_rate': 2.7919708029197082e-06, 'epoch': 2.58}
# {'loss': 0.4174, 'learning_rate': 2.7767639902676402e-06, 'epoch': 2.58}
# {'loss': 0.4015, 'learning_rate': 2.761557177615572e-06, 'epoch': 2.59}
# {'loss': 0.4339, 'learning_rate': 2.746350364963504e-06, 'epoch': 2.59}
# {'loss': 0.4655, 'learning_rate': 2.7311435523114362e-06, 'epoch': 2.59}
# {'loss': 0.436, 'learning_rate': 2.715936739659368e-06, 'epoch': 2.59}
# {'loss': 0.4839, 'learning_rate': 2.7007299270072994e-06, 'epoch': 2.6}
# {'loss': 0.42, 'learning_rate': 2.6855231143552314e-06, 'epoch': 2.6}
# {'loss': 0.434, 'learning_rate': 2.670316301703163e-06, 'epoch': 2.6}
# {'loss': 0.4486, 'learning_rate': 2.6551094890510954e-06, 'epoch': 2.6}
# {'loss': 0.3965, 'learning_rate': 2.639902676399027e-06, 'epoch': 2.6}
# {'loss': 0.4086, 'learning_rate': 2.624695863746959e-06, 'epoch': 2.61}
# {'loss': 0.3946, 'learning_rate': 2.6094890510948905e-06, 'epoch': 2.61}
# {'loss': 0.4378, 'learning_rate': 2.5942822384428225e-06, 'epoch': 2.61}
# {'loss': 0.4056, 'learning_rate': 2.5790754257907545e-06, 'epoch': 2.61}
# {'loss': 0.4559, 'learning_rate': 2.5638686131386865e-06, 'epoch': 2.62}
# {'loss': 0.4209, 'learning_rate': 2.548661800486618e-06, 'epoch': 2.62}
# {'loss': 0.4254, 'learning_rate': 2.53345498783455e-06, 'epoch': 2.62}
# {'loss': 0.4004, 'learning_rate': 2.518248175182482e-06, 'epoch': 2.62}
# {'loss': 0.4087, 'learning_rate': 2.503041362530414e-06, 'epoch': 2.63}
# {'loss': 0.4084, 'learning_rate': 2.4878345498783456e-06, 'epoch': 2.63}
# {'loss': 0.3838, 'learning_rate': 2.4726277372262776e-06, 'epoch': 2.63}
# {'loss': 0.4376, 'learning_rate': 2.4574209245742096e-06, 'epoch': 2.63}
# {'loss': 0.3906, 'learning_rate': 2.442214111922141e-06, 'epoch': 2.63}
# {'loss': 0.3929, 'learning_rate': 2.427007299270073e-06, 'epoch': 2.64}
# {'loss': 0.4344, 'learning_rate': 2.411800486618005e-06, 'epoch': 2.64}
# {'loss': 0.4244, 'learning_rate': 2.396593673965937e-06, 'epoch': 2.64}
# {'loss': 0.4214, 'learning_rate': 2.3813868613138688e-06, 'epoch': 2.64}
# {'loss': 0.4075, 'learning_rate': 2.3661800486618008e-06, 'epoch': 2.65}
# {'loss': 0.3861, 'learning_rate': 2.3509732360097328e-06, 'epoch': 2.65}
# {'loss': 0.4034, 'learning_rate': 2.3357664233576643e-06, 'epoch': 2.65}
# {'loss': 0.4208, 'learning_rate': 2.3205596107055963e-06, 'epoch': 2.65}
# {'loss': 0.3936, 'learning_rate': 2.3053527980535283e-06, 'epoch': 2.66}
# {'loss': 0.4247, 'learning_rate': 2.2901459854014603e-06, 'epoch': 2.66}
# {'loss': 0.3972, 'learning_rate': 2.274939172749392e-06, 'epoch': 2.66}
# {'loss': 0.3807, 'learning_rate': 2.2597323600973235e-06, 'epoch': 2.66}
# {'loss': 0.4178, 'learning_rate': 2.244525547445256e-06, 'epoch': 2.66}
# {'loss': 0.3669, 'learning_rate': 2.2293187347931875e-06, 'epoch': 2.67}
# {'loss': 0.4226, 'learning_rate': 2.2141119221411194e-06, 'epoch': 2.67}
# {'loss': 0.4335, 'learning_rate': 2.198905109489051e-06, 'epoch': 2.67}
# {'loss': 0.3845, 'learning_rate': 2.1836982968369834e-06, 'epoch': 2.67}
# {'loss': 0.4073, 'learning_rate': 2.168491484184915e-06, 'epoch': 2.68}
# {'loss': 0.4114, 'learning_rate': 2.1532846715328466e-06, 'epoch': 2.68}
# {'loss': 0.4233, 'learning_rate': 2.1380778588807786e-06, 'epoch': 2.68}
# {'loss': 0.4134, 'learning_rate': 2.1228710462287106e-06, 'epoch': 2.68}
# {'loss': 0.3997, 'learning_rate': 2.1076642335766426e-06, 'epoch': 2.68}
# {'loss': 0.4104, 'learning_rate': 2.092457420924574e-06, 'epoch': 2.69}
# {'loss': 0.4079, 'learning_rate': 2.077250608272506e-06, 'epoch': 2.69}
# {'loss': 0.4665, 'learning_rate': 2.062043795620438e-06, 'epoch': 2.69}
# {'loss': 0.4148, 'learning_rate': 2.04683698296837e-06, 'epoch': 2.69}
# {'loss': 0.3959, 'learning_rate': 2.0316301703163017e-06, 'epoch': 2.7}
# {'loss': 0.3539, 'learning_rate': 2.0164233576642337e-06, 'epoch': 2.7}
# {'loss': 0.3943, 'learning_rate': 2.0012165450121657e-06, 'epoch': 2.7}
# {'loss': 0.3832, 'learning_rate': 1.9860097323600973e-06, 'epoch': 2.7}
# {'loss': 0.3794, 'learning_rate': 1.9708029197080293e-06, 'epoch': 2.71}
# {'loss': 0.3838, 'learning_rate': 1.9555961070559613e-06, 'epoch': 2.71}
# {'loss': 0.4177, 'learning_rate': 1.9403892944038933e-06, 'epoch': 2.71}
# {'loss': 0.4229, 'learning_rate': 1.925182481751825e-06, 'epoch': 2.71}
# {'loss': 0.4046, 'learning_rate': 1.909975669099757e-06, 'epoch': 2.71}
# {'loss': 0.4529, 'learning_rate': 1.8947688564476888e-06, 'epoch': 2.72}
# {'loss': 0.4248, 'learning_rate': 1.8795620437956206e-06, 'epoch': 2.72}
# {'loss': 0.3408, 'learning_rate': 1.8643552311435526e-06, 'epoch': 2.72}
# {'loss': 0.406, 'learning_rate': 1.8491484184914844e-06, 'epoch': 2.72}
# {'loss': 0.3771, 'learning_rate': 1.8339416058394164e-06, 'epoch': 2.73}
# {'loss': 0.3863, 'learning_rate': 1.8187347931873482e-06, 'epoch': 2.73}
# {'loss': 0.4179, 'learning_rate': 1.8035279805352798e-06, 'epoch': 2.73}
# {'loss': 0.408, 'learning_rate': 1.788321167883212e-06, 'epoch': 2.73}
# {'loss': 0.4405, 'learning_rate': 1.7731143552311435e-06, 'epoch': 2.73}
# {'loss': 0.4153, 'learning_rate': 1.7579075425790757e-06, 'epoch': 2.74}
# {'loss': 0.4052, 'learning_rate': 1.7427007299270073e-06, 'epoch': 2.74}
# {'loss': 0.4211, 'learning_rate': 1.7274939172749395e-06, 'epoch': 2.74}
# {'loss': 0.4239, 'learning_rate': 1.712287104622871e-06, 'epoch': 2.74}
# {'loss': 0.4109, 'learning_rate': 1.6970802919708029e-06, 'epoch': 2.75}
# {'loss': 0.3957, 'learning_rate': 1.6818734793187349e-06, 'epoch': 2.75}
# {'loss': 0.4199, 'learning_rate': 1.6666666666666667e-06, 'epoch': 2.75}
# {'loss': 0.4684, 'learning_rate': 1.6514598540145987e-06, 'epoch': 2.75}
# {'loss': 0.4614, 'learning_rate': 1.6362530413625304e-06, 'epoch': 2.76}
# {'loss': 0.3607, 'learning_rate': 1.6210462287104624e-06, 'epoch': 2.76}
# {'loss': 0.3615, 'learning_rate': 1.6058394160583942e-06, 'epoch': 2.76}
# {'loss': 0.3851, 'learning_rate': 1.590632603406326e-06, 'epoch': 2.76}
# {'loss': 0.4062, 'learning_rate': 1.575425790754258e-06, 'epoch': 2.76}
# {'loss': 0.447, 'learning_rate': 1.5602189781021898e-06, 'epoch': 2.77}
# {'loss': 0.3825, 'learning_rate': 1.5450121654501218e-06, 'epoch': 2.77}
# {'loss': 0.4217, 'learning_rate': 1.5298053527980536e-06, 'epoch': 2.77}
# {'loss': 0.502, 'learning_rate': 1.5145985401459856e-06, 'epoch': 2.77}
# {'loss': 0.4454, 'learning_rate': 1.4993917274939174e-06, 'epoch': 2.78}
# {'loss': 0.4649, 'learning_rate': 1.4841849148418493e-06, 'epoch': 2.78}
# {'loss': 0.4162, 'learning_rate': 1.4689781021897811e-06, 'epoch': 2.78}
# {'loss': 0.3691, 'learning_rate': 1.453771289537713e-06, 'epoch': 2.78}
# {'loss': 0.4011, 'learning_rate': 1.438564476885645e-06, 'epoch': 2.79}
# {'loss': 0.3933, 'learning_rate': 1.4233576642335767e-06, 'epoch': 2.79}
# {'loss': 0.4039, 'learning_rate': 1.4081508515815087e-06, 'epoch': 2.79}
# {'loss': 0.3891, 'learning_rate': 1.3929440389294405e-06, 'epoch': 2.79}
# {'loss': 0.423, 'learning_rate': 1.3777372262773725e-06, 'epoch': 2.79}
# {'loss': 0.3969, 'learning_rate': 1.3625304136253043e-06, 'epoch': 2.8}
# {'loss': 0.4167, 'learning_rate': 1.347323600973236e-06, 'epoch': 2.8}
# {'loss': 0.4326, 'learning_rate': 1.332116788321168e-06, 'epoch': 2.8}
# {'loss': 0.4289, 'learning_rate': 1.3169099756690998e-06, 'epoch': 2.8}
# {'loss': 0.3947, 'learning_rate': 1.3017031630170318e-06, 'epoch': 2.81}
# {'loss': 0.394, 'learning_rate': 1.2864963503649636e-06, 'epoch': 2.81}
# {'loss': 0.3446, 'learning_rate': 1.2712895377128956e-06, 'epoch': 2.81}
# {'loss': 0.3776, 'learning_rate': 1.2560827250608274e-06, 'epoch': 2.81}
# {'loss': 0.3526, 'learning_rate': 1.2408759124087592e-06, 'epoch': 2.81}
# {'loss': 0.4224, 'learning_rate': 1.2256690997566912e-06, 'epoch': 2.82}
# {'loss': 0.3964, 'learning_rate': 1.210462287104623e-06, 'epoch': 2.82}
# {'loss': 0.3801, 'learning_rate': 1.195255474452555e-06, 'epoch': 2.82}
# {'loss': 0.372, 'learning_rate': 1.1800486618004867e-06, 'epoch': 2.82}
# {'loss': 0.4685, 'learning_rate': 1.1648418491484185e-06, 'epoch': 2.83}
# {'loss': 0.3822, 'learning_rate': 1.1496350364963505e-06, 'epoch': 2.83}
# {'loss': 0.3784, 'learning_rate': 1.1344282238442823e-06, 'epoch': 2.83}
# {'loss': 0.4255, 'learning_rate': 1.1192214111922143e-06, 'epoch': 2.83}
# {'loss': 0.4182, 'learning_rate': 1.104014598540146e-06, 'epoch': 2.84}
# {'loss': 0.4777, 'learning_rate': 1.088807785888078e-06, 'epoch': 2.84}
# {'loss': 0.4136, 'learning_rate': 1.0736009732360099e-06, 'epoch': 2.84}
# {'loss': 0.3809, 'learning_rate': 1.0583941605839416e-06, 'epoch': 2.84}
# {'loss': 0.4009, 'learning_rate': 1.0431873479318736e-06, 'epoch': 2.84}
# {'loss': 0.4007, 'learning_rate': 1.0279805352798054e-06, 'epoch': 2.85}
# {'loss': 0.3949, 'learning_rate': 1.0127737226277374e-06, 'epoch': 2.85}
# {'loss': 0.4149, 'learning_rate': 9.975669099756692e-07, 'epoch': 2.85}
# {'loss': 0.436, 'learning_rate': 9.823600973236012e-07, 'epoch': 2.85}
# {'loss': 0.406, 'learning_rate': 9.67153284671533e-07, 'epoch': 2.86}
# {'loss': 0.4055, 'learning_rate': 9.519464720194648e-07, 'epoch': 2.86}
# {'loss': 0.428, 'learning_rate': 9.367396593673967e-07, 'epoch': 2.86}
# {'loss': 0.4404, 'learning_rate': 9.215328467153286e-07, 'epoch': 2.86}
# {'loss': 0.3669, 'learning_rate': 9.063260340632604e-07, 'epoch': 2.86}
# {'loss': 0.4093, 'learning_rate': 8.911192214111923e-07, 'epoch': 2.87}
# {'loss': 0.438, 'learning_rate': 8.759124087591242e-07, 'epoch': 2.87}
# {'loss': 0.4412, 'learning_rate': 8.607055961070561e-07, 'epoch': 2.87}
# {'loss': 0.4016, 'learning_rate': 8.454987834549878e-07, 'epoch': 2.87}
# {'loss': 0.4117, 'learning_rate': 8.302919708029197e-07, 'epoch': 2.88}
# {'loss': 0.435, 'learning_rate': 8.150851581508516e-07, 'epoch': 2.88}
# {'loss': 0.3996, 'learning_rate': 7.998783454987835e-07, 'epoch': 2.88}
# {'loss': 0.4142, 'learning_rate': 7.846715328467154e-07, 'epoch': 2.88}
# {'loss': 0.4111, 'learning_rate': 7.694647201946472e-07, 'epoch': 2.89}
# {'loss': 0.4137, 'learning_rate': 7.542579075425791e-07, 'epoch': 2.89}
# {'loss': 0.3844, 'learning_rate': 7.39051094890511e-07, 'epoch': 2.89}
# {'loss': 0.3503, 'learning_rate': 7.238442822384428e-07, 'epoch': 2.89}
# {'loss': 0.4059, 'learning_rate': 7.086374695863747e-07, 'epoch': 2.89}
# {'loss': 0.4211, 'learning_rate': 6.934306569343066e-07, 'epoch': 2.9}
# {'loss': 0.4794, 'learning_rate': 6.782238442822385e-07, 'epoch': 2.9}
# {'loss': 0.4247, 'learning_rate': 6.630170316301704e-07, 'epoch': 2.9}
# {'loss': 0.3689, 'learning_rate': 6.478102189781023e-07, 'epoch': 2.9}
# {'loss': 0.4144, 'learning_rate': 6.326034063260342e-07, 'epoch': 2.91}
# {'loss': 0.4317, 'learning_rate': 6.17396593673966e-07, 'epoch': 2.91}
# {'loss': 0.4203, 'learning_rate': 6.021897810218979e-07, 'epoch': 2.91}
# {'loss': 0.4378, 'learning_rate': 5.869829683698297e-07, 'epoch': 2.91}
# {'loss': 0.4007, 'learning_rate': 5.717761557177616e-07, 'epoch': 2.92}
# {'loss': 0.3698, 'learning_rate': 5.565693430656935e-07, 'epoch': 2.92}
# {'loss': 0.4462, 'learning_rate': 5.413625304136254e-07, 'epoch': 2.92}
# {'loss': 0.4596, 'learning_rate': 5.261557177615572e-07, 'epoch': 2.92}
# {'loss': 0.3795, 'learning_rate': 5.109489051094891e-07, 'epoch': 2.92}
# {'loss': 0.415, 'learning_rate': 4.95742092457421e-07, 'epoch': 2.93}
# {'loss': 0.4001, 'learning_rate': 4.805352798053529e-07, 'epoch': 2.93}
# {'loss': 0.4209, 'learning_rate': 4.653284671532847e-07, 'epoch': 2.93}
# {'loss': 0.3597, 'learning_rate': 4.501216545012166e-07, 'epoch': 2.93}
# {'loss': 0.407, 'learning_rate': 4.3491484184914847e-07, 'epoch': 2.94}
# {'loss': 0.3991, 'learning_rate': 4.197080291970803e-07, 'epoch': 2.94}
# {'loss': 0.4039, 'learning_rate': 4.045012165450122e-07, 'epoch': 2.94}
# {'loss': 0.4405, 'learning_rate': 3.892944038929441e-07, 'epoch': 2.94}
# {'loss': 0.3909, 'learning_rate': 3.74087591240876e-07, 'epoch': 2.94}
# {'loss': 0.4038, 'learning_rate': 3.588807785888078e-07, 'epoch': 2.95}
# {'loss': 0.4142, 'learning_rate': 3.436739659367397e-07, 'epoch': 2.95}
# {'loss': 0.4397, 'learning_rate': 3.284671532846716e-07, 'epoch': 2.95}
# {'loss': 0.3714, 'learning_rate': 3.132603406326035e-07, 'epoch': 2.95}
# {'loss': 0.3996, 'learning_rate': 2.980535279805353e-07, 'epoch': 2.96}
# {'loss': 0.3933, 'learning_rate': 2.8284671532846716e-07, 'epoch': 2.96}
# {'loss': 0.4081, 'learning_rate': 2.6763990267639905e-07, 'epoch': 2.96}
# {'loss': 0.4199, 'learning_rate': 2.5243309002433095e-07, 'epoch': 2.96}
# {'loss': 0.3794, 'learning_rate': 2.3722627737226278e-07, 'epoch': 2.97}
# {'loss': 0.3514, 'learning_rate': 2.2201946472019467e-07, 'epoch': 2.97}
# {'loss': 0.4818, 'learning_rate': 2.0681265206812654e-07, 'epoch': 2.97}
# {'loss': 0.4314, 'learning_rate': 1.9160583941605843e-07, 'epoch': 2.97}
# {'loss': 0.3986, 'learning_rate': 1.7639902676399027e-07, 'epoch': 2.97}
# {'loss': 0.4047, 'learning_rate': 1.6119221411192216e-07, 'epoch': 2.98}
# {'loss': 0.4493, 'learning_rate': 1.4598540145985402e-07, 'epoch': 2.98}
# {'loss': 0.438, 'learning_rate': 1.3077858880778588e-07, 'epoch': 2.98}
# {'loss': 0.4015, 'learning_rate': 1.1557177615571777e-07, 'epoch': 2.98}
# {'loss': 0.3818, 'learning_rate': 1.0036496350364964e-07, 'epoch': 2.99}
# {'loss': 0.4035, 'learning_rate': 8.515815085158152e-08, 'epoch': 2.99}
# {'loss': 0.4156, 'learning_rate': 6.99513381995134e-08, 'epoch': 2.99}
# {'loss': 0.4056, 'learning_rate': 5.4744525547445264e-08, 'epoch': 2.99}
# {'loss': 0.4257, 'learning_rate': 3.9537712895377135e-08, 'epoch': 2.99}
# {'loss': 0.4014, 'learning_rate': 2.4330900243309006e-08, 'epoch': 3.0}
# {'loss': 0.408, 'learning_rate': 9.124087591240876e-09, 'epoch': 3.0}
#   0%|          | 0/488 [00:00<?, ?it/s]
# {'eval_loss': 0.37410688400268555, 'eval_runtime': 44.907, 'eval_samples_per_second': 173.536, 'eval_steps_per_second': 10.867, 'epoch': 3.0}
# {'train_runtime': 9758.7155, 'train_samples_per_second': 21.56, 'train_steps_per_second': 1.348, 'train_loss': 0.688838437634663, 'epoch': 3.0}
# TrainOutput(global_step=13152, training_loss=0.688838437634663, metrics={'train_runtime': 9758.7155, 'train_samples_per_second': 21.56, 'train_steps_per_second': 1.348, 'train_loss': 0.688838437634663, 'epoch': 3.0})

# %%
peft_para_model.save_pretrained('../model/para_ft_2')

# %% [markdown]
# ## Evaluation

# %%
class CosSimilarityPipeline():
    def __init__(self, model) -> None:
        self.model = model

    def _forward(self,inputs):
        embeds = self.model.encode(inputs)
        return embeds

    def _postprocess(self, outputs_inputs, outputs_targets):
        s = []
        for input_embd, target_embd in zip(outputs_inputs,outputs_targets):
            cos_sim = torch.nn.functional.cosine_similarity(torch.tensor(input_embd),torch.tensor(target_embd),dim=0)
            s.append(cos_sim)
        return torch.tensor(s)

    def __call__(self, inputs, targets,reduce_mean=True):
        input_embeds = self._forward(inputs)
        targets_embeds = self._forward(targets)
        sims = self._postprocess(input_embeds, targets_embeds)
        if reduce_mean:
            return torch.mean(sims).item()
        else:
            return sims.numpy()

# %%
toxicity_clf_tokenizer = RobertaTokenizer.from_pretrained(toxicity_classifier_name)
toxicity_clf_model = RobertaForSequenceClassification.from_pretrained(toxicity_classifier_name)
toxicity_clf_model.eval()

toxicity_clf_pipeline = pipeline('text-classification',tokenizer=toxicity_clf_tokenizer,model=toxicity_clf_model,device=torch_device)

sentence_similarity_model = SentenceTransformer(similarity_embedder_name)
sentence_similarity_model.eval()
cos_similarit_pipeline = CosSimilarityPipeline(sentence_similarity_model)

sacrebleu = evaluate.load(sacrebleu_name)
# Out:
# Some weights of the model checkpoint at SkolkovoInstitute/roberta_toxicity_classifier were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
def evaluate_metrics(toxicity_clf_pipe, similarity_clf_pipe,sacrebleu_metric, inputs, preds):
    with torch.no_grad():
        toxicities = toxicity_clf_pipe(preds)
        avg_tox = 0
        print('Toxicity computed')
        for row in toxicities:
            if row['label'] == 'neutral':
                avg_tox += (1 - row['score']) / len(toxicities)
            else:
                avg_tox += row['score'] / len(toxicities)

        cos_sim = similarity_clf_pipe(inputs,preds)
        print("Cosine similarity computed")

        bleu = sacrebleu_metric.compute(references=inputs, predictions=preds)['score']

    return {"toxicity": avg_tox,"cosine similarity": cos_sim,"bleu": bleu}

# %%
baseline_metrics = evaluate_metrics(toxicity_clf_pipeline,cos_similarit_pipeline, sacrebleu,test['reference'].to_list(), test['translation'].to_list())
print("Baseline metrix from dataset:\n", baseline_metrics)
# Out:
# Toxicity computed
# Cosine similarity computed
# Baseline metrix from dataset:
#  {'toxicity': 0.09911557480319434, 'cosine similarity': 0.6993823647499084, 'bleu': 22.748979964592944}

# %%
import tqdm.notebook as tqdm

def paraphrase(
    question,
    model,
    tokenizer,
    num_beams=5,
    num_beam_groups=5,
    num_return_sequences=5,
    repetition_penalty=10.0,
    diversity_penalty=3.0,
    no_repeat_ngram_size=2,
    temperature=0.7,
    max_length=128
):
    with torch.no_grad():
        tokenized = tokenizer(
            f'Paraphrase: {question}',
            return_tensors="pt", padding="longest",
            max_length=max_length,
            truncation=True,
        )
        tokenized = tokenized.to(torch_device)
        
        outputs = model.generate(
            **tokenized, temperature=temperature, repetition_penalty=repetition_penalty,
            num_return_sequences=num_return_sequences, no_repeat_ngram_size=no_repeat_ngram_size,
            num_beams=num_beams, num_beam_groups=num_beam_groups,
            max_length=max_length, diversity_penalty=diversity_penalty
        )

        res = tokenizer.batch_decode(outputs, skip_special_tokens=True)

    return res

def generate_single_paraphrases(model,tokenizer, inputs):
    preds = []
    for input in tqdm.tqdm(inputs):
        output = paraphrase(input,model, tokenizer, num_return_sequences=1)
        preds.append(output[0])
    return preds

# %%
general_model_preds = generate_single_paraphrases(peft_para_model,para_tokenizer, test['reference'])
# Out:
#   0%|          | 0/8659 [00:00<?, ?it/s]
# c:\Users\seofu\anaconda3\envs\pmldl\lib\site-packages\transformers\generation\configuration_utils.py:362: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.7` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(

# %%
general_model_metrics = evaluate_metrics(toxicity_clf_pipeline,cos_similarit_pipeline, sacrebleu, test['reference'].to_list(),general_model_preds)
print("Stock model:\n", general_model_metrics)
# Out:
# Toxicity computed
# Cosine similarity computed
# Stock model:
#  {'toxicity': 0.3095971209607241, 'cosine similarity': 0.716109037399292, 'bleu': 19.189722333388502}

# %%
from peft import PeftConfig, PeftModel
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

config = PeftConfig.from_pretrained('../model/para_ft_2')
model = AutoModelForSeq2SeqLM.from_pretrained(config.base_model_name_or_path)
model = PeftModel.from_pretrained(model, '../model/para_ft_2').to(torch_device)
model.eval()
tokenizer = AutoTokenizer.from_pretrained(config.base_model_name_or_path)
# Out:
# '(ReadTimeoutError("HTTPSConnectionPool(host='huggingface.co', port=443): Read timed out. (read timeout=10)"), '(Request ID: 59332935-8948-4750-8b67-43c3a63e5ea6)')' thrown while requesting HEAD https://huggingface.co/humarin/chatgpt_paraphraser_on_T5_base/resolve/main/config.json

# %%
ft_model_preds = generate_single_paraphrases(model,tokenizer, test['reference'])
# Out:
#   0%|          | 0/8659 [00:00<?, ?it/s]
# c:\Users\seofu\anaconda3\envs\pmldl\lib\site-packages\transformers\generation\configuration_utils.py:362: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.7` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(

# %%
ft_model_metrics = evaluate_metrics(toxicity_clf_pipeline,cos_similarit_pipeline, sacrebleu,test['reference'].to_list(),ft_model_preds)
print("Fine-tuned model:\n", ft_model_metrics)
# Out:
# Toxicity computed
# Cosine similarity computed
# Fine-tuned model:
#  {'toxicity': 0.5143966753414774, 'cosine similarity': 0.9037672281265259, 'bleu': 57.85035243169158}

# %%
from peft import PeftConfig, PeftModel
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

config = PeftConfig.from_pretrained('../model/para_ft_2')
model = AutoModelForSeq2SeqLM.from_pretrained(config.base_model_name_or_path)
model = PeftModel.from_pretrained(model, '../model/para_ft_2').to(torch_device)
model.eval()
tokenizer = AutoTokenizer.from_pretrained(config.base_model_name_or_path)

def detoxify(text, model, tokenizer, toxicity_evaluator_pipeline, cos_sim_pipeline, num_generate_sequences=5,return_metrics=True):
    with torch.no_grad():
        paraphrased_texts = paraphrase("Paraphrase: " + text, model, tokenizer,num_return_sequences=num_generate_sequences,num_beams=5 if num_generate_sequences ==1 else num_generate_sequences)
        toxicities = toxicity_evaluator_pipeline(paraphrased_texts)
        postprocessed_detoxicities = []
        for row in toxicities:
            if row['label'] == 'neutral':
                postprocessed_detoxicities.append( row['score'])
            else:
                postprocessed_detoxicities.append(1-row['score'])
            
        similarities = cos_sim_pipeline(paraphrased_texts, [text]*num_generate_sequences,reduce_mean=False)

        if num_generate_sequences > 1:
            means = np.mean(np.stack([postprocessed_detoxicities, similarities],axis=1),axis=1)
            best_id = np.argmax(means)
            output = paraphrased_texts[best_id]
            metrics = {'toxicity': 1 - postprocessed_detoxicities[best_id], 'similarity': similarities[best_id]}
        else:
            output = paraphrased_texts[0]
            metrics = {'toxicity': 1 - postprocessed_detoxicities[0], 'similarity': similarities[0]}

    if return_metrics:
        return output, metrics
    else:
        return output
    

def evaluate_chained_model(model,tokenizer, inputs):
    preds = []
    avg_tox = 0.0
    avg_sim = 0.0
    for input in tqdm.tqdm(inputs):
        output, metrics = detoxify(input ,model, tokenizer, toxicity_clf_pipeline, cos_similarit_pipeline,num_generate_sequences=10)
        preds.append(output)
        avg_tox += metrics['toxicity'] / len(inputs)
        avg_sim += metrics['similarity'] / len(inputs)
    bleu = sacrebleu.compute(references=inputs, predictions=preds)['score']
    return {"toxicity": avg_tox,"cosine similarity": avg_sim,"bleu": bleu}

# %%
ft_chained_models_metrics = evaluate_chained_model(model, tokenizer, test['reference'])

# %%
print(ft_chained_models_metrics)
# Out:
# {'toxicity': 0.019775867462158203, 'cosine similarity': 0.5927732586860657, 'bleu': 31.947155212313625}

# %% [markdown]
# # Inference

# %%
from peft import PeftConfig, PeftModel
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

config = PeftConfig.from_pretrained('../model/para_ft_2')
model = AutoModelForSeq2SeqLM.from_pretrained(config.base_model_name_or_path)
model = PeftModel.from_pretrained(model, '../model/para_ft_2').to(torch_device)
model.eval()
tokenizer = AutoTokenizer.from_pretrained(config.base_model_name_or_path)

# %%
def detoxify(text, model, tokenizer, toxicity_evaluator_pipeline, cos_sim_pipeline, num_generate_sequences=5,return_metrics=True):
    with torch.no_grad():
        paraphrased_texts = paraphrase("Paraphrase: " + text, model, tokenizer,num_return_sequences=num_generate_sequences,num_beams=5 if num_generate_sequences ==1 else num_generate_sequences)
        toxicities = toxicity_evaluator_pipeline(paraphrased_texts)
        postprocessed_detoxicities = []
        for row in toxicities:
            if row['label'] == 'neutral':
                postprocessed_detoxicities.append( row['score'])
            else:
                postprocessed_detoxicities.append(1-row['score'])
            
        similarities = cos_sim_pipeline(paraphrased_texts, [text]*num_generate_sequences,reduce_mean=False)

        if num_generate_sequences > 1:
            means = np.mean(np.stack([postprocessed_detoxicities, similarities],axis=1),axis=1)
            best_id = np.argmax(means)
            output = paraphrased_texts[best_id]
            metrics = {'toxicity': 1 - postprocessed_detoxicities[best_id], 'similarity': similarities[best_id]}
        else:
            output = paraphrased_texts[0]
            metrics = {'toxicity': 1 - postprocessed_detoxicities[0], 'similarity': similarities[0]}

    if return_metrics:
        return output, metrics
    else:
        return output

# %%
detoxify(test['reference'].iloc[5], model, tokenizer, toxicity_clf_pipeline, cos_similarit_pipeline,num_generate_sequences=10)
# Out:
# ("you're a clever little guy.",
#  {'toxicity': 0.0006096363067626953, 'similarity': 0.83392817})
